# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeYamamoto/test/blob/main/csv_io.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

filename="韓国から中国まとめ.csv"
df = pd.read_csv(filename)

# %%
df_c = df.loc[:,["Country"]]
# print(df_c)
counry=df_c[~df_c.duplicated()]

cnt = df['Country'].str.split(',')
Country = []

for i in cnt:
    if i not in Country:
        Country.append(i)

print(Country)
print(counry)
print(len(Country))
# print(df_c[~df_c.duplicated()])
# Out:
# [['韓国'], ['カンボジア'], ['シンガポール'], ['スペイン'], ['タイ'], ['台湾'], ['中国']]
#      Country
# 0         韓国
# 72     カンボジア
# 74    シンガポール
# 437     スペイン
# 544       タイ
# 1465      台湾
# 1931      中国
# 7

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.7/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.6.15)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2022.9.1)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)

# %%
#国名ファイル用　日本語　→　英語
from googletrans import Translator
 
tr = Translator()
CountryText=[]
for i in range(len(Country)):
      result=[i,Country[i]]
      countryText="".join(Country[i])
      result = tr.translate(countryText, src="ja", dest="en").text
      CountryText.append(result)

print(CountryText)
# Out:
# ['Korea', 'Cambodia', 'Singapore', 'Spain', 'Thailand', 'Taiwan', 'China']

# %% [markdown]
# Driveとマウントする必要がある
#
# *   https://okazukun5.com/122/
#
# **国とTextのみのファイル出力**

# %%
import csv

# CSVファイルの保管先
csv_path = "/content/drive/MyDrive/out/"

for i in range(len(Country)):
  rm_Country=[]
  # CSVファイル名＝国名
  countStr= "".join(Country[i])
  csv_name = countStr+(".csv")

  f = open(csv_path+csv_name, 'w',encoding='utf-8_sig',newline='')
  writer = csv.writer(f)


  #国ごとにText抽出
  dfS=df[df['Country'].isin(Country[i])]
  text = dfS['Text'].str.split(',')
  for i in text:
    # print(i)
    rm_Country=[i]
    writer.writerow(rm_Country)
  f.close()

# %%
#確認
import csv
with open('/content/drive/MyDrive/out/アイルランド.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)

# %% [markdown]
# **出力**

# %%
# 国ごとのtext読み込み
# CSVファイルの保管先
csv_path = "/content/drive/MyDrive/out/"

for i in range(len(Country)):
  rm_result=[]
  # CSVファイル名＝国名
  countStr= "".join(Country[i])
  csv_name = countStr+(".csv")

  with open(csv_path+csv_name, newline='') as f:
    lines = f.readlines()

    print(lines)
# Out:
# ["\ufeff['韓国語初心者のための歯科通訳サービスはどうですか?']\r\n", "['江南駅の近くにある、ホワイトドリーム歯科へ矯正に通っています。こちらの歯科は、日本語が通じるので、矯正相談も丁寧にのってもらえます。先生も治療についての説明を丁寧にわかりやすく話してくださるのでいつも安心できます。治療費のことも相談すると親切に対応してくれました。腕の良い、安心して通える矯正歯科を探していれば、ホワイトドリーム歯科をお勧め致します。']\r\n", "['お尋ね致します。サムスンのタブレットs7のLTEのSM-T875を愛用しているのですが、電池の持ちが当初に比べて悪くなってきました。ネットで調べて見るとBt875aby という型番の電池みたいですが、韓国でサムスンの純正品を購入した場合、いくらでしょうか?又、日本へ発送してくれる販売店などをご存知のかた、居られたら、ご教示いただければありがたいです。非純正品を使って発火したりするのが怖いので、サムスンと 銘の入ってない互換部品は使いたくないし、サムスンジャパンに相談しても対応できなかったので
ので、質問した次第です。']\r\n", "['子どもを自転車（チャイルドシート）に乗せる時、子どもの日焼け防止は何をされてますか？ 娘がまだ1歳なのですが、ユニクロのエアリズムはサイズ110からしか置いておらず。。 日差しが強いので、何かしら予防したいのですが皆様のお子様を自転車に乗せる時の格好や、日焼け止め以外でどのように日焼けを予防されてるかや、日焼け防止グッズをどこで購入されたかなど教えて下さい。']\r\n", "['外出時のお子さんのトイレ、どうされていますか？モール内などのトイレが汚いところが多く、ショックを受けています。子供は最近トイレで用を足せるようになりましたが、子供に使わせるのを躊躇するぐらいの衛生状態のトイレが多いです。たとえ拭いても座らせる気には全くなりません。きれいなところも時々はありますが…。現在はなるべく長時間の外出は避けています。男の子で、一度女性トイレに小便器があった時は立ってさせましたが、ないところだったらどうしようと今から怖いです。みなさんはお子さんのトイレはどうやって対処されていますか？小さなことでも良いのでアドバイス頂きたいです。']\r\n", "['水道メーターの読み方について。 今月はじめから一人暮らしをはじめ、月末の為、色々計算しております。水道メーターの読み方がわからず困っているのですが、以下のキャプチャですと何立方メーター利用したことになるか教えていただけると助かります。4000立方メートルかと読めるのですが、そんなに1ヶ月で使ったおぼえがなく混乱しています。 宜しくお願いします']\r\n", "['シンガポールでワーホリをする予定なのですが現役大学生なので職務経験がなく(日本では飲食のアルバイト程度)、海外の長期滞在が初で英語力にも不安があります。 どのような職が向いてると思いますか？また、職探しの良いサイトがあれば教えてほしいです。']\r\n", "['大人用の不織布マスクは、どのようなお店/場所で購入できるのでしょうか。できれば色や柄が入っているもの希望です。オンラインは配達日数がかかるので、できれば現物をすぐ購入できるお店が良いのですが、WATSONS/GUARDIANなどの大手薬局ではサージカル用の青、白、黒色のシンプルなものしか見かけません。色や柄が入った不織布マスクの販売場所をご存知の方、教えて頂けますか。よろしくお願いいたします。']\r\n", "['米びつの中の虫を防ぐ方法を教えてください。 日本で売ってるような米びつ見張り番みたいなものをこちらで購入したいのですが、英語でなんと検索したら出てくるのでしょうか？']\r\n", "['最近新しいヘルパーさんを迎えたのですが、彼女は前の家では赤ちゃんの面倒がメインの仕事だったらしく、料理はあまりやったことがありません。それで、最初は、料理は私が作るから洗い物をやってもらおうと思っていたのですが、やはり疲れて料理をしたくない日もあり、そんな時に家でヘルパーさんに何か作ってもらえたら、すごく助かるなと思い始めました。 皆さん、ヘルパーさんがいるご家庭はどんな料理を作ってもらっていますか？私が教えやすく、ヘルパーさんが作りやすい料理であれば嬉しいです。料理教室に行ってもらう等ということは今のところ考えておりません＾＾；']\r\n", "['ローカルスーパーに行くとWHIPPING CREAMとCOOKING CREAMが複数メーカーから出ており、同じメーカーでも両方とも乳脂肪35%というのも見かけました。何が違い、どう使い分けるのでしょうか？ババロアやムースなどお菓子を作る際に必要な、泡立てない生クリームは、どちらがオススメでしょうか？教えて頂ければ幸いです。']\r\n", "['美容皮膚科、その他クリニックにてダーマペンをやっているところがあれば教えて下さい。日系、ローカル、問いません。若い頃に酷かったニキビ跡の治療、このマスク生活のうちに根本的にやるつもりです。リジュランは数回トライしました
の成立は別としてメールを受信したら返信するのが一般常識かと思うんですが、 今の時代の人達の考えは違うんですかね。']\r\n", "['タイ人のお給料について。タイは転職でキャリアをつけて給料を上げるようです。それからタイはすっと 給料が上がり続けてますよね？そのことから、１０年前に採用した人間と数年前に採用した人間の基本給に かなり差が出てしまいもめています。タイ人同士でお話しして判明してしまったようです。差は月額で４，５０００円程度です。社内でも評価が低かったため、その評価金額を元にするベースアップがまた低く、それが積み重なりかなり差が開いたようです。落としどころは、何があるでしょうか？...']\r\n", '"[\'Sick Leave（傷病休暇）をずる賢く使うスタッフがいて困っております。月に1\', \'2回朝から下痢と言っては傷病休暇を使い、周りのスタッフもあれはズル休みですよと言う始末で、かと言って、証拠がつかみにくいのでズル休みが重なっているので解雇の対象というわけにいかず対処に困っております。Sick Leaveにすべて医師の診断書をつけさせるのも実質的には難しいかと思うのですが、皆様のところにこのようなずる賢くSick Leaveを使うスタッフへうまい対処をしているところはございますか？Sick...\']"\r\n', "['タイ語検定取っててタイ語話せる人見たことないです。私ははタイ語を話せるのですが、タイ語検定持ってる人と同席してもいつも通訳させられます。タイ語学校通ってる人もタイ語検定勉強されてる方も何を目標（ゴール）にしてやられてるのか謎です。']\r\n", "['タイで車を運転していて困ること、わからないルールについて教えて下さい。']\r\n", "['かかとの角質を取る軽石、何処で売っていますか？ フジ2スーパーには無いようですが。']\r\n", "['「駐妻生活を語ろう」の続きはこちらからお願いします。-- 2021-12-26 追記 --ー追記ー12/26 掲示板の乗っ取りをしてる方へ。削除よろしくお願いします。']\r\n", "['先日日本へ家財等を送ったのですが、クラウドバトラーという引越し業者にお願いしました。ここは日本人がやっているので安心だと思って送ったら…、凄く高いグラスを紙で包み、固定もせずにほかの食器と合わせて送ってきたので、ほとんど壊れてしまいました。色々と交渉をしていましたが、多数のウソをつき、こちらの話も聞いておらず、郵便業者が悪いと一点張りで話になりません。 梱包の仕方も全部丸めて入れたような入れ方で、自分でやった方が断然きれいにできるような仕上がり。常識が通じないので、絶対おすすめしません！']\r\n", "['サターンの利用方を教えてください。 銀行では両替してもらえません']\r\n", "['お世話になります。現在マレーシア在住の者です。これから猫1匹（5才）とタイ移住を考えております。日本からマレーシアへ移住する際にも手続きはしましたが、外国から外国へ移住するのが初めてで何か特別な手続きがないか懸念しております。もしマレーシア（外国）からタイへ移住する際の手続きにお詳しい方いましたら教えていただきたいです。また、移住の際は極力ニャンコから離れず手運びしたいのですが、陸路などでペット手運びで移住することは可能でしょうか。よろしくお願いいたします。']\r\n", "['タイにいる独身の日本人女性は30代以上が大半だと思います。婚活してる女性もいると思いますが、あなたと結婚するメリットは何ですか？失礼ですが、結婚適齢期（平均初婚年齢）は過ぎている方が大勢います。タイにはどんな理由があって働いているのですか？海外経験のためですか、駐在員の旦那を見つけるためですか？なぜこの日本人女性はタイで働いているんだろうと考えさせる方が1人２人ではないので、こんなトピックを立てるのはいかがなものかとも思いましたが議論する余地があれば残っていくだろうと思いトピ立てさせていただきました。...']\r\n", "['ヤワラートでハイドロフラスクというおしゃれな水筒のアウトレット品が売っていると聞きました。 どこの何というお店なのか、ご存知の方がいらっしゃいましたら、教えていただけないでしょうか。']\r\n", "['来年の4月末にチェンマイへと考えております! 初め初めはまず視察に行きたいと考えております! その後年間180日を超えない程度で数年を予定しておりますが どのビザを選択すれば良いのか迷っております! この場を使わせて頂き質問させてもらいました。 何分にも現在日本以外の国にて生活しており ます 何卒宜しくお願い致します!']\r\n", "['小さなお子さん(小学生低学年)をお持ちの方で、外で遊ばせたい場合、お勧めの場所があれば教えて下さい。出来れば、有料遊技場等ではなく、タイの子供や他の外国のお子さんたちと一緒に遊ばせたいです。以前は、セントラルワールドの無料の遊び場が好きで、よく行っていましたが、撤去されて以降は、同じような場所を探すのに苦労しています。ソイ２６奥の、屋内サッカー場の隣にある建物にたまに行くのですが、無料遊具も規模が小さく、子供は直ぐに飽きてしまいます。他の子供も殆どいないため、皆さんはどこで遊ばせているのか不思議に思い質問させていただきました。']\r\n", "['こんにちは、来月からタイに赴任するために引っ越しの準備中です。お気に入りのコーヒーメーカーを使いたいため、アップダウントランス対応の変圧器の購入を考えています。調べると、日本から持参される、または帰国される駐在員の方から譲ってもらう、などが多いようですが、タイの現地で変圧器を購入することはできるのでしょうか。それとも日本で購入して引っ越し荷物に入れる方が良いでしょうか。カシムラの変圧器を使用されている方が多いようですが、2000Wまたは3000W対応の変圧器を日本で購入すると40000円程度するので値段の高さに少し悩んでおります。...']\r\n", "['2週間ほど日本に一時帰国します。タイで購入し使用している携帯電話の契約キャリアはAISです。この携帯を日本に持ち込んで滞在中に日本国内で使用したい。使用条件(要望)は・LINE等のネット環境は現状のまま使用したい。・日本国内での電話通信の場合、日本国内の業者が私の携帯にかける場合\\u3000+66は押さないで済むようにしたい。・その為に日本の電話番号に変わっても問題ない。ネット検索すると”カードを購入して云々”と言う情報がいっぱいあって結局コスパが優れている方法は何か選択が難しい。最近誰かこう言う体験をされた方はどう言う方法があるのかご教示頂ければと思います。']\r\n", "['９月にプーケットに行きます。帰国する際にPCR検査が必要との事、安くて証明書を出して頂ける病院等があるか教えていただけますでしょうか。 よろしくお願いいたします。']\r\n", "['はじめまして。どうぞよろしくお願いします。 タイに行きます。コロナ禍前には何度か行ったことがあります。30日まではビザ免除で何も必要ありませんでした。 現在はワクチンを接種していれば特に必要なことはないと解釈していますが、事前に準備することや必要なものはありますでしょうか？ ご教示くださると嬉しいです。']\r\n", "['サワディーチャオマッチングアプリで知り合った子とバンコクに行くのですが、現在ゴーゴーボーイのお店は開いてますでしょうか？youtuberをやっている子のようでそれなりに取れ高もほしいということも言ってまして。情報お持ちの方おしえてください。コップンチャオディッキーでしたー']\r\n", "['来年から、タイ、バンコクに赴任します。 高校生の子供が２人がいます。インターナショナルスクールでお勧めがあれば教えてください。 学費はできれば、100万前後が望ましいのです。 ＊子供の英語レベルは、英検準２級、準3級']\r\n", "['バンコクでいちばんラノベや漫画の品揃いがいいkinokuniyaって何処ですか？']\r\n", "['タイの納税に詳しい方に質問です。タイでは個人の納税者番号を発行してくれるものでしょうか？※オンラインビジネス用のプラットフォームに登録するためのものです。※どこかの会社に所属した場合にも個人納税番号は発行可能でしょうか。']\r\n", "['現在９か月の子供を育てています。今月末の連休を利用し３泊４日の旅行を計画していますが、子供の食事に不安があり、アドバイスを頂戴できればと思います。・現在離乳食中期～後期になる段階。柔らかいごはんにお肉や魚、野菜を混ぜたものがメイン。副菜につかみ食べできる野菜や、お豆腐、スープ、バナナやヨーグルトを食べさせています。・１日３回離乳食・普段は手作りですが、日本で買ったレトルトは食べられます。４日分（12食）は確保していますが、レトルトだけだ ...
# ["\ufeff['こんにちは。 仕事で台湾の高雄に来ている28歳男です。 高雄から新幹線で台北に行きたいのですが、乗り方も駅までの行き方も分からず困っており投稿させて貰いました。 最寄駅はzuoyingです。 もしよければどなたか教えて頂きたいです。 よろしくお願い致します。']\r\n", "['こんにちは。 現在台北に住んでいる者です。 諸般の事情により近いうちに一度出境する必要があるのですが、私はワクチンを接種しておらず陰性証明書が必要なため、できるだけ安く取得できる医療機関を探しています。 なお、渡航先は日本ではない第三国のため、日本の厚生労働相が求めるフォーマットでなくても問題ありません。 宜しくお願いします。']\r\n", "['台北市から新北市に転居します。この場合、居留証の変更手続きは台北市(廣州街）の移民局で出来ますか？新北市の移民局は中和で遠く、新居からだと台北の移民局の方が近くて便利です。ご存知の方がいらっしゃいましたら、ぜひ教えてください。']\r\n", "['閲覧ありがとうございます。娘の将来の仕事について、悩んでいます。中学生の娘が、３年ほど前から教師になりたいと言うんです。一過性のものと聞き流してたんですが、大学受験や高校選びも、それを意識しているようなんです。このご時世に、割りに合わない職を選んでほしくないのが本音です。他所の子供を教育するなんて、神経すり減ることでしょうし、労働時間も気になるところです。親はグループでねちこく突いてくるでしょう。...']\r\n", "['初めまして、閲覧ありがとうございます。当方台北に在住している者です。現在2歳になったばかりの子供がいるのですがともかくマスクを付ける事を拒否してしまします…。何度か付けてみない？とチャレンジしているのですがマスクを近づけるだけでも嫌がり仮に付けることが出来ても秒で外してしまいます。（ちなみに帽子も嫌いでかぶらせてもすぐ取ってしまします）...']\r\n", "['PCR検査の質問です。台北市内、もしくは新米市で、唾液検査を受けられる病院は有りますか？幾つかの病院に問い合わせましたが、鼻に綿棒を差し込む？タイプの検査だと言われました。ニュースなどで見ると痛そうですが、実際のところどうなのでしょうか？台北市・新米市以外でも構いませんので、どなたか実際に唾液検査を受けた方がいらっしゃれば教えて下さい。宜しくお願いいたします。']\r\n", "['日本へ一時帰国の際、携帯電話はどうされていますか？ SIM購入？ 中華電信に申し込み？ 良い方法があればご教示ください。']\r\n", "['台北で『ダーマペン4』が受けられるクリニックはありますか？調べたらなさそうですが。。。']\r\n", "['台湾出国前のPCR検査について質問です。現在日本への帰省を考えています。今は台湾から出国する際、48時間以内のPCR検査が必要になるかと思います。ここまでは分かるのですが、色々調べてみると指定のフォーマットの証明書でなければいけないとの事ですが、指定のフォーマットというのは病院で『2日後に出国する際提出するので、それ用の証明書が欲しい』という風に伝えれば良いのでしょうか？また六歳の子供がいるのですが、子供の分もPCRは必要なのでしょうか？ここの病院が良いよ、というオススメ等もあれば、ぜひ教えていただきたいです。...']\r\n", "['産後の抜け毛について、アドバイスがあれば教えてください…（涙）']\r\n", "['台北市内で小児を診てくれる、日本語の通じる歯医者さんを探しています。 ご存じの方は教えて頂けないでしょうか？']\r\n", "['子供を連れて日本に一時帰国します。 しばらく日本に滞在するので住民票を入れる予定です。 その後は台湾と日本を行き来すると思うのですが、住民票はみなさん入れたままにしていますか？抜いていますか？ 台湾人配偶者のため生活は台湾ベースにはなるのですが、日本帰国時に子供が病院に行くことを考えるとこのままにしておきたいのですが…。']\r\n", "['助けてください。もうどうしていいかわかりません。以下、重い内容になりますのでごめんなさい。台湾北部、台北郊外に暮らす日本人主婦です。主人は台湾人です。...']\r\n", "['プロ使用包丁 ネノックス筋引きか牛刀を扱っているお店を探してます！ 自分の目で見て買いたいと思ってます。']\r\n", "['台北の天母以外の地区で、2歳半から入れる幼稚園（日本語で対応してくれる）を探しています！ 幼い子供2人を連れて駐在予定であり、台湾での子育て情報を集めてますが、なかなか分からなくて日々不安でいっぱいです。 どなたか、オススメの幼稚園や日本人が多く通っている幼稚園を知っている方がいたらぜひ、教えてください！']\r\n", "['台北で美味しいショートケーキを探しています ご存知の方いらっしゃいましたら教えてください！']\r\n", "['こんにちは！当方、日本人と台湾人の新婚夫婦で台北市在住です。7月31日から台湾政府より家賃補助の申請が可能だそうで、受給対象の条件には当てはまっているのですが台湾の大家は家賃収入に関して税金を払っていないのが大部分らしく、申請する際に今住むアパートの大家に申請の旨を伝えると「家賃収入が政府に知られたら税金払わないといけないので申請をするな」との事でした...法律上は大家の同意無しに申請は可能ですが、そうすると今後のトラブルにも繋がりかねないらしく、どう対処すれば良いのか分かりません。しかし補助額がかなり多いので、大いに家庭の助けになります......']\r\n", "['林口で物件を探しています。 日本語の通じるエージェントをご存知の方は教えていただけると助かります。']\r\n", "['はじめまして。台湾在住でもなく、予定もないのですが、質問させてください。台湾では薄切り肉はスーパー等で簡単に手に入りますか？過去に何カ国か在住経験があり、どの国も薄切り肉を入手するのは困難でした。アジア系スーパーや、スーパーで時々あっても冷凍のみでした。他国での入手事情に興味があり、ブログなどをググってみるとほとんどの国は上記のようにあまり簡単ではないのですが、台湾に関してはそのような記事が発見できませんでした。このことから、台湾では薄切り肉は身近に売られているのかな？と想像したのですが、実際はいかがですか？興味があります！']\r\n", "['添付した写真のような子供の使う『忘れ物チェッカー』が欲しいのですが、どこか売っている場所を知っている方がいれば教えて下さい。蝦皮でも思いつく単語で検索してみたのですが、一向に引っかからずで。。よろしくお願いいたします。']\r\n", "['台北で保冷剤が見つからず困っています。 何処で購入できるでしょうか。 ネットでの購入ではなく、お店などで購入出来ればと思います。']\r\n", "['誰か一緒にクラブ行こーやー！台湾に留学中の学生でーす！男女問わず集まろ〜！-- 2022-06-25 追記 --下のコメントで教えてね']\r\n", "['今年の11月に台湾人の旦那と台湾で生活することが決まりました。 子供が現在2人おり、上の子が2歳
今度上海に出張で伺う予定で以下のVPNを検討しております。NordVPNhttps://nordvpn.com/ja/what-is-a-vpn/']\r\n", "['お尋ね致します。昨年辺りに香港で販売されていたレノボのタブレット p11 pro Lte、多分、型番はZa7d0096hk 当時2999hk$ をまだ販売していて、日本配送に対応してくれるとこはありませんか? 日本にはp11 pro のlteはないので、購入を考えてます。']\r\n", "['某有名ラーメンチェーンの歌舞伎町店の社長さんが香港移住されたそうですが、以前いろいろお世話になってきっちり御礼したいので連絡先を探しています。何か情報をご存知の方がいらしたらコメントよろしくお願いします。']\r\n", "['ベッドやソファーなど大型家具を処分したい のですが、安価で引取りして頂ける業者さん など知っている方おられましたら教えて 下さい。 宜しくお願いします。']\r\n", "['この度、誤って日本製の炊飯器を変圧器を通さず使用してしまい壊してしまいました。案の定炊飯器からボンっと聞こえたので基盤が壊れてしまったのかと思います。買い替えがベストだとは承知しているのですが、御祝いで頂いた品のため修理できるならしたいと考えています。もし同じような経験をされた方で、香港で修理された方がいらっしゃれば情報を共有頂けると大変嬉しく思います。よろしくお願い申し上げます。']\r\n", "['アトピーによる皮膚炎の薬（ステロイド塗り薬）を処方してくれる病院を探しています。 日系または日本語が通じる皮膚科は前回1000HKD超と非常に診察料が高く、もう少しお安く診療してくれる先を探しています。 ご存知の方がいらっしゃれば教えていただきたいです。']\r\n", "['北京で子供用バイオリンの修理をしてくれるお店を探しています。どこか評判の良いお店を教えて頂けないでしょうか？']\r\n", "['妊婦健診でおすすめの産婦人科を教えて頂きたいです。診療代が比較的安いとありがたいです。駅近だと嬉しいですが場所は問いません。よろしくお願いします。']\r\n", "['飼い主の代理で愛犬を動物病院に連れて行ってくださる方を探しています。日時：３月１日（明日）\\u3000\\u3000\\u3000午前８：４５〜午前１１時まで（早く終わる可能性もあります）場所：深水埗HKD：１０００ご連絡をお待ちしております。']\r\n", "['日本へ一時帰国してからまた香港へ戻る際に出発48時間以内に香港政府が認めるPCR検査について、①関西圏\\u3000②首都圏\\u3000それぞれにおいて、費用をできるだけ抑えて検査ができるところを探しています。\\u3000 よろしければ情報をいただけますとさいわいです。']\r\n", "['香港で買えるものもらいに効く薬を探しています。 ローカルでも日本の物でも構いません。 教えてください。よろしくお願いします。']\r\n", "['最近、日本から香港への郵便物が配達されるのが極端に遅くないですか？ 東京都内で１０月4日に投函したエアメールが10月23日に届いて、10月6日に投函したエアメールはまだ届きません。 みなさんどうでしょう？']\r\n", "['日本に入国する際に必要な日本政府が要求するフォーマットでのPCR検査での陰性証明書を出せる香港の医療機関は領事館のページに一覧のリストはありますが、値段などの点でおすすめのところはあるでしょうか。']\r\n", "['香港でおすすめの雀荘ご存じないでしょうか？できれば自動卓で個室あり、英語or日本語が使用できるようなところを探しているのですが。']\r\n", "['ヘルパーさんへのクリスマスプレゼントやお年玉についてお伺いしたいです。 ヘルパーさんを雇っていらっしゃる方で、クリスマスプレゼントやお年玉をご用意される場合、一般的には何をどのくらいの金額（もしくは現金）をご用意されますでしょうか。 一般的な相場が分からず、参考にさせた頂きたいです。よろしくお願い申し上げます。']\r\n", "['画像の商品を探しています。 商品名、売っている場所がわかれば教えてください!!']\r\n", "['はじめまして。 北京にこれから引っ越す者ですが、学校情報を得たいと思い投稿しました。 インターナショナルを考えています。 人気の学校、日本人が良くいく学校は何処ですか？ バスだと30分ぐらいは当たり前でしょうか！？ またドイツ学校についても何か知っていましたら教えて下さい！よろしくお願い申し上げます。']\r\n", "['私は、城西国際大学大学院 経営情報学研究科に通う学生です。現在、日本親会社と中国現地法人の関係性について研究をしております。お忙しい中恐れ入りますが、もし宜しければ下記のURLよりアンケートにご回答いただいたくお願い申し上げます。\\u3000対象者：在中日系企業にお勤めの日本人の方\\u3000URL：https://forms.office.com/r/6iwyQQf0LL\\u3000所要時間：5分程度以上、宜しくお願いいたします。']\r\n", "['日本人20代女性です 香港から日本の郵貯銀行に送金する方法を教えてください。 それから誰か送金できる方いませんかお金は渡してから送金で構いません。 詳しく教えて欲しいのでcanmakejapan@gmail.com line airakaki']\r\n", "['香港で探しているものがあります。 Calousell等見てみましたが、見つかりません。 香港に捜し物サイトはありますでしょうか。(こちらから○○を探していますと投稿できるサイト) あれば教えていただけますか。']\r\n", "['2022年から2023年にかけて、ワーホリを使い香港留学を計画してます。年齢もワーホリの限度まで引っ張り、31か32歳で渡航します。日本では飲食業に携わっていたので、和食か鮨のお店で働いてみたい想いがあります。香港の家賃はとても高いので、シェアハウスやホームステイを考えてますが、住居含め、仕事先を今から探す為には日本からのエージェントなど活用した方が良いでしょうか？また、渡航までに英語、広東語も勉強して少しは話せるようになりたいと思ってます。もし、ワーホリ経験者の方や日本での準備期間について、良いアドバイスがありましたらご教授頂ければ幸いです。よろしくお願いします。']\r\n", "['はじめまして。現在東南アジアに家族でいます。来年度引っ越す予定ですが、全く中国、北京について無知でございます。そこでアドバイスを頂けたら助かります。安全性、どのあたりに住めば便利か？日本人街があるのか？食についてコロナの状況、子育てしやすい環境か、、、などなどお願いします。']\r\n", "['現在付き合っている香港人の彼氏と来年結婚予定ですが、香港で仕事が見つかるか不安です。皆さんは香港に行く前に、どうやって香港での仕事を見つけられたのでしょうか？海外エージェントに登録・相談したとかでしょうか？どのように香港での仕事を見つければ良いでしょうか。たまに、香港プラス職種で検索して求人を見るようにしてます。30代前半で中国語中級ぐらいで、コロナのこともあるので、仕事探しは難航すると思いますが、そもそも探し方が分からないので質問してみました。よろしくお願いします。']\r\n", "['香港内で七五三の撮影、着物レンタルを含むサービスを提供していただける所はないでしょうか。または着物がレンタルできるお店を探してます。よろしくお願いします。']\r\n", "['上海での家族帯同の最新情報( ...

# %%
# !pip install textacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textacy
#   Downloading textacy-0.11.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 6.8 MB/s
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.6.3)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.7.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.21.6)
# Collecting cytoolz>=0.10.1
#   Downloading cytoolz-0.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 66.6 MB/s
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.0.2)
# Collecting jellyfish>=0.8.0
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 72.9 MB/s
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.64.1)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (3.4.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.23.0)
# Collecting pyphen>=0.10.0
#   Downloading pyphen-0.13.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 40.1 MB/s
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.2.4)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.1.0)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz>=0.10.1->textacy) (0.12.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (8.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.10.1)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (4.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.9.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.0->textacy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0.0->textacy) (5.2.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->textacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=73992 sha256=65e6ee95f89d5fb03e876329055c10228dc05d1d95c456f3c33d757b8b9f94a5
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# Installing collected packages: pyphen, jellyfish, cytoolz, textacy
# Successfully installed cytoolz-0.12.0 jellyfish-0.9.0 pyphen-0.13.0 textacy-0.11.0

# %%
# !pip install -U pip setuptools wheel > /dev/null 2>&1
# !pip install -U spacy > /dev/null 2>&1
# !python -m spacy download ja_core_news_sm > /dev/null 2>&1
# !pip install neologdn > /dev/null 2>&1

# %%
#!python -m spacy download ja_core_news_md

# %%
#!python -m spacy download ja_core_news_lg

# %%
# !pip install emoji --upgrade > /dev/null 2>&1

# %%
# !pip install ginza > /dev/null 2>&1
# !pip install -U ginza ja-ginza  > /dev/null 2>&1
# !python -m spacy download ja_core_news_sm > /dev/null 2>&1

# %%
import pandas as pd
import emoji
import numpy as np
import neologdn
import re
import string
import csv
from typing import List, Tuple
import spacy
from spacy.lang.ja import Japanese, DetailedToken
from textacy import extract
import ginza # 動作モード切替のため

# %%
import emoji
import re

def remove_emoji(text):
   '''
   remove all of emojis from text
   '''
   text=  emoji.demojize(text)
   text= re.sub(r'(:[!_\-\w]+:)', '', text)

   return text

# %%
# 前処理
def preprocess(x):
  x=remove_emoji(x)
  #絵文字の除去
  emoji_pattern = re.compile(
            "["
            "\U0001F600-\U0001F64F"  # emoticons
            "\U0001F300-\U0001F5FF"  # symbols & pictographs
            "\U0001F680-\U0001F6FF"  # transport & map symbols
            "\U0001F1E0-\U0001F1FF"  # flags (iOS)
            "]+",
            flags=re.UNICODE,
        )

  x = emoji_pattern.sub(r"", x)

  x = neologdn.normalize(x)
  x = x.lower()
  x = re.sub(r"https?://[\w/:%#\$&\?\(\)~\.=\+\-]+", "", x)#URLの除去
  x = re.sub(r"[!\?%-/:-@[-`{-~]", r" ", x)# 半角記号の置換
  x = re.sub("[■-♯]", "", x)# 全角記号の置換 (ここでは0x25A0 - 0x266Fのブロックのみを除去)
  x = re.sub(r"(\d)([,.])(\d+)", "\1\3", x)#桁区切り (+ 小数点) 除去
  # x = re.sub(r"\d+", "0", x)#数字を0に置換
  # x = re.sub(r"\d+","" ,x)#数字除去
  x = re.sub(r'[a-zA-Z0-9]', '', x)#英数字除去
  x = re.sub(r"・", ", ", x)#・→，
  x = re.sub(r"[\(\)「」【】]", "", x)# 括弧削除（まだ消すやつある）
  x = re.sub(r"[\！\？＝＋－\+\*\-\&\(\)\.\,/=\-，．。、\ ￥’”→↓←↑…「」（）『 \・～『』・；：⚫※％]","", x)

  

  return x

# %%
#extract後の可視化
def decompose_keyterms(keyterm_list: List[str]) -> Tuple:
    terms = [el[0] for el in keyterm_list]
    scores = [el[1] for el in keyterm_list]
    return terms, scores

#トークン化
def create_doc(text):
  nlp = spacy.load('ja_ginza')
  mode="C"
  ginza.set_split_mode(nlp, mode) # モード切替
  doc = nlp(text)
  return doc

# %%
#textrank
def textrank_algo(doc):
    include_pos=["NOUN", "PROPN", "ADJ"]#英語の品詞タグ名詞形容詞動詞，
    textrank = extract.keyterms.textrank(doc, normalize="lower",include_pos=include_pos,topn=30)
    terms_textrank, scores_textrank = decompose_keyterms(textrank)

    return terms_textrank, scores_textrank

#PositionRank
# def PositionRank_algo(doc):
#     include_pos=["NOUN", "PROPN", "ADJ"]#英語の品詞タグ名詞形容詞動詞，
#     PositionRan = extract.keyterms.textrank(doc, normalize="lemma",include_pos=None,window_size=10, edge_weighting="count", position_bias=True,topn=20)
#     terms_PositionRank, scores_PositionRank = decompose_keyterms(PositionRan)

#     return terms_PositionRank, scores_PositionRank

#yake
def yake_algo(doc):
    include_pos=["NOUN", "PROPN", "ADJ"]#英語の品詞タグ名詞形容詞動詞，
    yake = extract.keyterms.yake(doc, normalize="lower",include_pos=include_pos,ngrams=(2, 3),topn=30)
    terms_yake, scores_yake = decompose_keyterms(yake)

    return terms_yake, scores_yake

#scake
def scake_algo(doc):
    scake = extract.keyterms.scake(doc, normalize="lemma")
    terms_scake, scores_scake = decompose_keyterms(scake)

    return terms_scake, scores_scake

#sgrank
def sgrank_algo(doc):
    include_pos=["NOUN", "PROPN", "ADJ"]#英語の品詞タグ名詞形容詞動詞，
    sgrank = extract.keyterms.sgrank(doc, normalize="lower",include_pos=include_pos,ngrams=(2, 3),topn=30)
    terms_sgrank, scores_sgrank = decompose_keyterms(sgrank)
    return terms_sgrank, scores_sgrank

# %%
#品詞でフィルタリング
def preprocessPOS(text):
  doc = create_doc(text)

  #英語の品詞タグでストップワード作成
  rmPOS=["PUNCT", "NUM", "SYM","PRON","INTJ","SCONJ","AUX","PART","CCONJ","ADV","ADP","SPACE","VERB","DET"]
  filtere = [rmtoken.text for rmtoken in doc if rmtoken.pos_ in rmPOS]
  # print(filtere)
  #日本の品詞タグでストップワード作成
  stopTag=["感動詞-フィラー","感動詞-一般","補助記号-句点","補助記号-一般","補助記号-読点","記号-一般","記号-文字","名詞-数詞","名詞-普通名詞-助数詞可能","	名詞-普通名詞-副詞可能","代名詞","接尾辞-名詞的-助数詞","接尾辞","接尾辞-名詞的-一般","接尾辞-名詞的-副詞可能","接尾辞-名詞的-サ変可能","接頭辞","助動詞","助詞-係助詞","助詞-格助詞","助詞-終助詞","助詞-副助詞","助詞-準体助詞","副詞","連体詞"]
  filter1 = [token.text for token in doc if token.tag_ in stopTag]
  # print(filter1)
  #ストップワード結合
  filtere_all = filtere+filter1

  filtered_doc = [token.text for token in doc if not token.text in filtere_all]

  Str = " ".join(filtered_doc)# list -> str
  
  return Str

# %%
#spacy
def spacy_result(doc):
  taken=[]
  for tok in doc.ents:
    if tok.text:
      # print(tok.text,"   ",tok.label_)
      taken.append(tok.text)
      
  # print(set(taken))
  return set(taken)

# %%
spacy.explain("GPE")#xpacyのラベル確認
# Out:
# 'Countries, cities, states'

# %% [markdown]
# **StopWord**

# %%
def stopwords_text():
  stopword_file = open("Newstopwords.txt", "r")

  stopword = []

  w=stopword_file.readlines()
  # print(w)
  for line in w:
    # print (line)
    if line != '\n':
      # print (line.split()[0])
      stopword.append(str(line.strip()))

  return stopword

# %%
def rm_stopword(x):
  sl=stopwords_text()
  result=[]

  for token in x.split( ):
    # print(token)
    if not token in sl:
      result.append(token)
  w=set(result)
  strResult=  " ".join(w)# list -> str 
  # print(strResult)

  return strResult

# %% [markdown]
# **csvまとめて分割 ＆ キーフレーズ抽出** **太字**

# %%
import csv
# 呼び出し・結果

# CSVファイルの保管先
csv_path1 = "/content/drive/MyDrive/out/TextRank/"
csv_path2 = "/content/drive/MyDrive/out/sgRank/"
csv_path3 = "/content/drive/MyDrive/out/YAKE/"

# CSVファイルの保管先
op_csv='/content/drive/MyDrive/out/'

for i in range(len(Country)):
  # CSVファイル名＝国名
  c_name="".join(CountryText[i])
  countStr= "".join(Country[i])

  with open(op_csv+countStr+(".csv"), newline='') as f:
    lines = f.readlines()

  chunks = [' '.join(lines[i:i+95]) for i in range(0, len(lines), 95)]

  fTextRank = open(csv_path1+c_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
  writer_textRank = csv.writer(fTextRank)

  fYAKE = open(csv_path2+c_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
  writer_yake = csv.writer(fYAKE)

  fsgRank = open(csv_path3+c_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
  writer_sgRank = csv.writer(fsgRank)

  textRank=[]
  yake=[]
  sgRank=[]
  PositionRank=[]
  
  for chunk in chunks:
    # rmPOS=preprocessPOS(chunk)
    # pre = preprocess(rmPOS)
    # doc = create_doc(pre)

    rmPOS="".join(chunk)
    pre = preprocess(rmPOS)
    doc = create_doc(pre)

    terms_textrank, score_textrank = textrank_algo(doc)
    terms_yake, score_yake = yake_algo(doc)
    # terms_scake, score_scake = scake_algo(doc)
    terms_sgrank, scores_sgrank = sgrank_algo(doc)
    # terms_PositionRank, scores_PositionRank = PositionRank_algo(doc)

    textRank+=terms_textrank
    yake+=terms_yake
    sgRank+=terms_sgrank
    # PositionRank+=terms_PositionRank

    setResult1=set(textRank)
    result1=[]
    for a in setResult1:
      rm=rm_stopword(a)
      result1+=[rm]

    setResult2=set(yake)
    result2=[]
    for j in setResult2:
      rm2=rm_stopword(j)
      result2+=[rm2]

    setResult3=set(sgRank)
    result3=[]
    for k in setResult3:
      rm3=rm_stopword(k)
      result3+=[rm3]
      
    result1=list(filter(None, set(result1)))
    result2=list(filter(None, set(result2)))
    result3=list(filter(None, set(result3)))

    for t in result1:
      t1=[countStr,t]
      writer_textRank.writerow(t1)

    for y in result2:
      y1=[countStr,y]
      writer_yake.writerow(y1)

    for s in result3:
      s1=[countStr,s]
      writer_sgRank.writerow(s1)

本人', '以内', '塾', '購入', 'タイ 人 エアコン', '場所 良い', 'タイ 移住', 'バンコク 銀行', '段 ベット', 'タイ 料理', '日本 以外', '電気代', '一度 タイ', 'バンコク 赴任', '色んな', 'お仕事 良い', '方法', '情報', 'バンコク 日本人', '学校 ご存知', 'バンコク 大学', 'タイ 質問', '入国 日本', 'タイ 戦', '男性 人', '感 日本', '語 タイ', '飲食店 タイ', '皮', '人 現地', 'ご存知', '両替', '使い心地', 'セット 歯ブラシ', '業者 タイ 人', '管理 会社', '購入 予定', '日本 両親', 'バンコク 掲示板', '同士 タイ 人', '私たち', '受講', '連絡 ご', 'バンコク 伊勢丹', '利用', 'タイ 自由', 'ラーメン 屋', '先生', '遊び場', 'ピアノ 電子', '購入 可能', 'バンコク ホアヒン', '日本語 日本人', '向け 日本人', 'カード ラビット', '心ない', '情報 生活', 'スタジオ ご存知', 'バンコク 付近', '紹介 ご', 'ペット', '来 タイ', 'タイ 政府', 'オンライン ショップ', '女性 タイ 人', 'バンコク', '入国 タイ', '掲示板 タイ', '店 マッサージ', 'お店 ご存知', '出産 タイ', '禍 コロナ', '系 タイ 人', 'インター 幼稚園', '日本 代表戦', 'エリア ご存知', '検定 語 タイ', '国籍 タイ', '様 タイ', '様', 'バンコク 市', 'バンコク 近郊', 'バンコク 首都', '日系 幼稚園', '感想', '詳しい', '国内 タイ', 'お店 情報', '返金 デポジット', '会社', '帰国 本', 'ベッド 日本', '修理 日本', '条件 中心街', '外国人', '料金', '人', '許可', '日本 サッカー', '古式 タイ', '学校 日本人', '滞在', '対 タイ', '日本 タイ', '同時 配信', '日本 伝統', '市内 バンコク', 'ネット', 'タイ 国外', '社 タイ', '妻', '生活 妻', 'バンコク 現地', '夜', 'バンコク 人', 'タイ', '登録', 'お店 ネット', 'スタッフ タイ 人', 'バンコク 日間', 'バンコク チェンマイ', '語学 学校', '女 日本人', '経験', '是非', '日本 人宿', '駐 妻', '日本', '労働許可証', 'タイ 在住', 'バンコク ヤンゴン', '日本 タイ 双方', '多い 人', '日本 将来', '会社 日本人', 'バンコク 病院', 'バンコク 初心者', 'タイ 当方', '日本 亭', '安い バンコク', 'タイ 人', '文字 タイ', 'ない 人 モラル', '現地 日本人', 'バンコク 都内']
# sgrank タイ ['連絡 ご', '用品 子供', 'ラーメン 屋', 'ピアノ 電子', 'カード ラビット', '現地 採用', 'オンライン ショップ', '修理 屋', '段 ベット', '店 マッサージ', 'タイ 料理', '禍 コロナ', '語 タイ', '様', 'バンコク 市', '詳しい', '駐 生活 妻', 'タイ 人', 'セット 歯ブラシ', '返金 デポジット']
# textrank 台湾 ['対応 頂ける', '台湾 東部 地震 未明', '台湾 現地 企業', '着物', '以外 日本人', '市内 追記 当方 台北 在住', '高雄 台湾', '日本人 雰囲気 特徴 率 情報 周辺', '名前 年齢 出身 西暦 生まれ 地生 職業', '台湾 ワーホリ', '台湾 人', '両替 当日 頂ける', '台湾 配偶者 人', '台北 日本人 在住', '付近 桃園 台北 新北', '台湾 ベース', 'モデルナ 台湾 副反応 人', '動物園 子ども 北部 市内 夜市 台湾 台北 福村 以外 木柵', '留学 予定 正規', '中国語 日本語', '郊外 台湾 台北 北部', '台湾 滞在', '特殊 訓練 発表 表現 受賞 証書 証明書 専業 著作', '台湾 生活', '台湾 長い', '先輩 諸', '出身 台湾', '未就学児 路線 航空券 済み 羽田 松山 購入', '書店 雰囲気 ドリンク 料金 施設 サーバー 図書館', '様 台湾', '連絡', '台北 観光', '中国語 英語 割', 'サークル 日本語 イベント 授業 体操 歌 活動 主', '楽しい ライフ 台湾', '台湾 郵便局', '市 台北 新北', '台湾 在住', '洋洋 懶 生 兔 羊 猴 之 十二 肖', '周辺 台北', '掲示板 台北', '台湾 フリーランス 在住', '台湾 陸運局', '悪い 人 気持ち 台湾', '近く 台湾 歴年 在住', '入国 台湾', 'ワクチン 副反応 何回', '行き 台湾', '全身 受 除毛 日本 在', '華語 台湾', '資 民 統一 免許証 號基 國 パスポート 中華 表 證', '出産 月子 中心 病院', '痒み 体質 アレルギー 肌荒れ', '情報', 'ご存知 病院', 'アニメ 旅 番組 情報 テレビドラマ テレビ', '姐 製作 黃騰 飛 妹', '弾丸 旅行 ピーチ 泊', '台湾 哥', '市 台北', '在留 届', '台湾 旦那 人', '日本語 英語 堪能 奥様 主婦', 'ご存知', '台湾 企業', '二人 子供', '時給 元', '台湾 赴任', '台湾 料理', '台湾 週間 隔離 自主', '市 台北 在住', '台湾 マーケット', '台湾 フルーツ', 'アニメ キャラクター グッズ 生活 雑貨', '経験 詳しい', '証 日本人 妻 居留', '大学 休学', 'センター 宜 大學 逢甲 国立 靜 大学 教育 中興 語学 台中', '市 エリア 台北 新北', '台湾 人 彼氏', '中国 台湾', '初 台湾', '幼い 人 子供', '台北', '台湾 女性', '台湾 男性', '元 台湾', '點 什麼 女 嗎還 元 推薦 回答 起 有我 來地 兩個 預算 吃牛 不 台北 有 加 餐廳 朋友', '好 来 ひろ 心 園 幼児 愛', '知恵', '情報 以外', '場所 你好 台北', '詳しい', '国籍 台湾', '台中 台北', '市 以外 台北 新米', '良心 相場 対応 日本語', '台湾 銀行', '台北 新北', '場合 台湾', '台湾', 'スクール 情報', '台湾 スタッフ 人', '台湾 卒業後', '日本 メーカー', '日本 女性 短大卒', '台湾 台北', '台湾 在住者', '市内 台北 日本語', '台湾 育ち', '場合 日本', '妊娠 日本 帰国', '桃園 新北 林口 台北 周辺', '籍 台湾', '系 目的 出会い', '日本', '学生', '市内 中山 区 台北駅 台北 信義 周辺', '台湾 年間', '台北 在住', '台湾 期間 入境', '日本 帰国', '人 日本人', '国籍 名前 年齢 生 職業', '特別 外来 日本人', '高雄 台北 台湾', '学生 ビザ', '台湾 この頃', '会 場所 日本人', '旅行 台湾', '台湾 バージョン', '台湾 政府', '台湾 出国', '禁止 ビジネス コース 中国語 使用', '提供 情報']
# yake 台湾 ['着物', '以外 日本人', '高雄 台湾', '泊', '回答 台北', '人 子供', '台湾 ワーホリ', '台湾 人', '台湾 配偶者 人', '出会い', '台湾 期間', '台湾 台北 北部', '頂ける', '台湾 ベース', '国産 ワクチン', '先輩', '台湾 滞在', 'ビザ 居留', '台湾 生活', '台湾 長い', '中国語 英語', '出身 台湾', '情報 ご存知', '動物 病院', '悪い 台湾', '様 台湾', '連絡', '台湾 現地', '初 台北', '台北 観光', '郊外 台北', '台湾 郵便局', '台湾 在住', '周辺 台北', '掲示板 台北', '台湾 陸運局', '台湾 隔離', '入国 台湾', '行き 台湾', '場所 台北', '華語 台湾', '市 台北', 'ご存知', '両替', '市 新北', '台湾 企業', '場所 日本人', '台湾 赴任', '台湾 料理', '台湾 マーケット', '楽しい 台湾', '台湾 フルーツ', '身近', '你好 台北', '初 台湾', '日本 料理', '台北', '台湾 女性', '台湾 男性', '元 台湾', '東京 台北', '台北 點', '留学 正規', '様', '知恵', '留学 予定', '情報 以外', '詳しい', '国籍 台湾', 'ワクチン コロナ', '台北 当方', '台中 台北', '日本 インターネット', '台湾 銀行', '台北 新北', '学校 日本人', '台湾 入境', '場合 台湾', '情報 番組', '台湾', '台湾 卒業後', '相談', '農園', '産 日本', '台湾 台北', '主婦 日本人', '語学 学校', '経験', '台湾 育ち', '場合 日本', '籍 台湾', '大学', '日本', '証 居留', '台北 在住', '台湾 年間', '日本 帰国', 'いらっしゃっ', '高雄 台北 台湾', 'ライフ 台湾', '台湾 この頃', '駐在 予定', '旅行 台湾', '台湾 バージョン', '台湾 政府', '旅行', '付近 台北', '台湾 出国']
# sgrank 台湾 ['台湾 人', 'ビザ 居留', '留学 正規', '学校 日本人', '市 新北', '詳しい', '動物 病院', '証 居留', '市内 台北', '泊', '旅行', '語学 学校', '市 台北']
# textrank 中国 ['親会社 日本', '日時 午前', '香港 経由', 'お仕事', '城 哈尔 滨是 和 交流 市', '賃料 押金 数か月', '感受 非常 冷 吗 我 过手 和 脚 没 左右 世界 亲身', '多い 香港', '学校 日本人', '表 演 你们 期待', '政府 香港', 'か月 仲介手数料 賃料 家賃', '空港 ターミナル 香港', 'プラス 香港 職種', '家来 单的 迎 语欢', '线连 接 始 干 层的 和 机 新 场的 工程 议开 了 用 站 最高 会 新潟', '郵便局 日本人 学校 日本 スーパー 中国語', '滞在 香港', '諸経費 送料 込み', '首 日本 为', '生活 香港', '日本 配送', '日本 会社 通関', '仲介手数料 賃料 家賃 押金', '所要時間', '可能 対応 日本人', '旅行 香港', '日本 在住', '日本 為', '想 和 上海 空 交流 在 有 朋友 广东', '証明 学', '日本 政府', '科 日本 語学', '以 可 据 大家 根', '日系 通販 日本食 レストラン デパート', '想 演还 表 提供 各 样的 种各', '日本 便', '日本', '香港', '詳しい システム', '市', '日本 ラーメン おいしい 屋', 'チケット ウェブ チェックイン 済み 無し 印刷 荷物', '通 过高 速 东京 铁道 站 与', '名古屋 シドニー 区間 香港', '人 香港', 'シティホール 香港', '语 教 朋友 广东 们给', '詳しい 価格 相場', '学 相 习我 互 普通 会 说', '詳しい', 'ビザ 最新 情報 招聘 状', '点 直播 呈现 现场 开始 为您', '島 香港', '住宅', '留学 香港']
# yake 中国 ['方法 良い', '日本 学校', '親会社 日本', '香港 経由', 'お仕事', '押金', '多い 香港', '上海', '空港 虹橋', '日本 ラーメン', '良い 先生', '政府 香港', '仲介手数料 家賃', '中国語', 'お店 良い', '相場', '滞在 香港', '日本 スーパー', '生活 香港', '日本 配送', '仲介手数料', '空港 香港', '所要時間', '旅行 香港', '日本 在住', '日本 為', '日本 おいしい', 'シドニー 香港', 'プラス 香港', '学', '教育 企業', '空港 浦東', '賃料', '日本 政府', '日本 便', '香港', '日本', '子育て 教育', 'イヤー コスプレ', '市', '名古屋 香港', '日本 通関', '北京 師範', '中国語 学校', '人 香港', 'シティホール 香港', '詳しい', '日本 語学', 'システム', '島 香港', '区間 香港', '住宅', '歯列 矯正', '留学 香港']
# sgrank 中国 ['イヤー コスプレ', '空港 香港', '歯列 矯正']

# %% [markdown]
# 以下テスト実行用

# %% [markdown]
# **TextRank**

# %%
# 呼び出し・結果
#すべて実行

# CSVファイルの保管先
op_csv='/content/drive/MyDrive/out/'
csv_path = "/content/drive/MyDrive/out/TextRank/TextRank_Korea_/"

for i in range(len(Country)):

  # CSVファイル名＝国名
  c_name="".join(Country[i])
  countStr= "".join(Country[i])
  csv_name = c_name+(".csv")

  with open(op_csv+csv_name, newline='') as f:
    lines = f.readlines()

  chunks = [' '.join(lines[i:i+100]) for i in range(0, len(lines), 100)]


  fo = open(csv_path+csv_name, 'w',encoding='utf-8_sig',newline='')
  writer = csv.writer(fo)

  textRank=[]
  yake=[]
  sgRank=[]
  PositionRank=[]

  for chunk in chunks:
    # rmPOS=preprocessPOS(chunk)#品詞タグでストップワード設定
    rmPOS="".join(chunk)
    pre = preprocess(rmPOS)
    doc = create_doc(pre)

    terms_textrank, score_textrank = textrank_algo(doc)

    textRank+=terms_textrank
    setResult=set(textRank)

    for i in setResult:
      result=[countStr,i]
      print(result)
      
      writer.writerow(result)
  fo.close()

# %% [markdown]
# **それぞれのアルゴリズム出力**

# %%
import csv
# 呼び出し・結果
textRank=[]
yake=[]
sgRank=[]
PositionRank=[]

country="オーストラリア"

with open("/content/drive/MyDrive/out/"+country+".csv", newline='') as f:
  lines = f.readlines()

chunks = [' '.join(lines[i:i+95]) for i in range(0, len(lines), 95)]
print(chunks)

# CSVファイルの保管先
csv_path1 = "/content/drive/MyDrive/out/TextRank/"
csv_path2 = "/content/drive/MyDrive/out/sgRank/"
csv_path3 = "/content/drive/MyDrive/out/YAKE/"
# CSVファイル名
csv_name = "オーストラリア"

# fTextRank = open(csv_path1+csv_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
# writer_textRank = csv.writer(fTextRank)

# fYAKE = open(csv_path2+csv_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
# writer_yake = csv.writer(fYAKE)

# fsgRank = open(csv_path3+csv_name+(".csv"), 'w',encoding='utf-8_sig',newline='')
# writer_sgRank = csv.writer(fsgRank)


for chunk in chunks:
    rmPOS=preprocessPOS(chunk)
    pre = preprocess(rmPOS)
    doc = create_doc(pre)

    # rmPOS="".join(chunk)
    # pre = preprocess(rmPOS)
    # doc = create_doc(pre)

    # terms_textrank, score_textrank = textrank_algo(doc)
    terms_yake, score_yake = yake_algo(doc)
    # terms_scake, score_scake = scake_algo(doc)
    terms_sgrank, scores_sgrank = sgrank_algo(doc)

    # terms_PositionRank, scores_PositionRank = PositionRank_algo(doc)

    # textRank+=terms_textrank
    yake+=terms_yake
    sgRank+=terms_sgrank

    # PositionRank+=terms_PositionRank

    #TextRank
    # setResult1=set(textRank)
    # result1=[]
    # for i in setResult1:
    #   rm=rm_stopword(i)
    #   result1+=[rm]

    #YAKE
    setResult2=set(yake)
    result2=[]
    for j in setResult2:
      rm2=rm_stopword(j)
      result2+=[rm2]

  #sgRank
    setResult3=set(sgRank)
    result3=[]
    for k in setResult3:
      rm3=rm_stopword(k)
      result3+=[rm3]
      
# result1=list(filter(None, set(result1)))
result2=list(filter(None, set(result2)))
result3=list(filter(None, set(result3)))

# for t in result1:
#     a=[country,t]
#     writer_textRank.writerow(a)

for y in result2:
    a=[country,y]
    # writer_yake.writerow(a)

for s in result3:
    a=[country,s]
    # writer_sgRank.writerow(a)

# # fTextRank.close()
# fYAKE.close()
# fsgRank.close()


# prin
# t("textrank", result1)
print("yake",result2)
print("sgrank",result3)
# print("PositionRank",PositionRank)
# Out:
# ["\ufeff['野球をしたいのですがゴールドコーストで、日本人の野球コミニティなどあったりしますか？']\r\n ['初めまして。東京都北区在住のyukiと申します。紆余曲折ありましたが、4月中旬に31歳になってしまうことをキッカケにこれがラストチャンスだと思い、年齢もタイミングも貯金もギリギリの状態で、来月ついにワーホリしようと考えています。先週ようやく英文残高証明書の発行を依頼し、到着まで２週間近くかかると言われたため、４月４日の週にビザ申請の予定です。【この掲示板で知りたいこと】①４月中旬～５月中旬頃に募集してくださるシドニー近郊のオペアまたは家がどこにあるか...']\r\n ['はじめましてこんにちは。 8月にゴールドコーストに訪問を予定しておりまして、8/13日のAFLのチケットGold Coast Suns v Geelong Catsを購入したいのですが、どちらで購入可能でしょうか？ ネット購入や現地で安価で仕入れる方法等ご存知でしたらご教示いただけますと幸いです。 よろしくお願いいたします！']\r\n ['情けなく詐欺被害に遭いました。日本からの契約だった為、インスペクション無しでボンドとレントを振込、その後スチームカードの購入を促され、この時点で怪しく思い断り全てをキャンセルしたところ、返信が無くなりました。現在オーストラリアにいる為、被害届も出せません、、対象記事とやり取りをしたオーストラリア人のアドレスと名前、振込先名義(何故か日本人)楽天銀行\\u3000アルト支店ミナミザワ\\u3000コウキを記載します。現在もここも含めいくつかのクラシファイドサイトでこの人の投稿記事をみかけますので、皆様お気をつけください。']\r\n ['はじめまして。現在メルボルン在住、数年後にクイーンズランドに引っ越しを考えているものです。ブリスベンとゴールドコーストの中間か、ケアンズかで迷っているのですが、もしよければケアンズでの暮らしについて教えてください。※現在クイーンズランドは賃貸が大変な競争率だとニュースで見たんですが、ケアンズはどうでしょうか？パートナーと二人なので、2〜3ベッドほどで考えています。※ケアンズは空港が近いです
', '改革 体内', '読書 カフェレストランキャンベラキャンベラ', '食材', '意識 改革 体内', 'クラシファイドサイト', '英語', '家庭 一般', 'ゲンタシン 市販', '勉強 読書', 'スビアコ 友達', 'オーストラリア 葬儀', '有り難い 情報', '語学 ワーホリ', '良い 就労ビザ', '出産 シドニー', '支店 アルト', '不安 困り事', '不安 シドニー', '忙しい 動画', '場所 市販', 'ビザ 学生', '方法 幸い ご存知', '毛嚢炎 ゲンタシン', '歯医者 ゴールドコースト', '病院 痛く', '日本 文化', '資格 母国 看護師', 'シドニー 脱毛', '記事', '回答 ご存知', '治安 名前', 'ツイッター 動画', '情報', '友達 作り', 'シドニー 東京', '日本人 友達']

# %% [markdown]
# **yake**

# %%
# 呼び出し・結果
yake=[]

# CSVファイルの保管先
op_csv='/content/drive/MyDrive/out/'
csv_path = "/content/drive/MyDrive/out/YAKE/"

for i in range(len(Country)):

  # CSVファイル名＝国名
  countStr= "".join(Country[i])
  op_csvName = countStr+(".csv")
  csv_name = countStr+("2.csv")

  with open(op_csv+op_csvName, newline='') as f:
    lines = f.readlines()

  chunks = [' '.join(lines[i:i+100]) for i in range(0, len(lines), 100)]
  
  for chunk in chunks:
    rmPOS=preprocessPOS(chunk)
    pre = preprocess(rmPOS)
    doc = create_doc(pre)
    
    # rmPOS="".join(chunk)
    # pre = preprocess(rmPOS)
    # doc = create_doc(pre)

    terms_yake, score_yake = yake_algo(doc)

    yake+=terms_yake
    
  setResult=set(yake)
  for a in setResult:
    result=[countStr,a]
    print(result)


  print("yake",terms_yake)
    # fo = open(csv_path+csv_name, 'w',encoding='utf-8_sig',newline='')
    # writer = csv.writer(fo)

    
    # for i in setResult:
    #   result=[countStr,i]
    #   print(result)
      
    #   writer.writerow(result)
    # fo.close()
# Out:
# ['韓国', '日本語 教師']
# ['韓国', '家具 家電']
# ['韓国', '丁寧 いつも']
# ['韓国', '良い 矯正歯科']
# ['韓国', '在住 日本人']
# ['韓国', '実費 保険']
# ['韓国', '江南駅 近く']
# ['韓国', '丁寧 先生']
# ['韓国', '歯科 矯正歯科']
# ['韓国', '韓国人 女性']
# ['韓国', '矯正 丁寧']
# ['韓国', 'アンケート 調査']
# ['韓国', '韓国語 オススメ']
# ['韓国', '歯科 通訳']
# ['韓国', 'ホワイト ドリーム']
# ['韓国', '韓国語 初心者']
# ['韓国', 'ホワイト ドリーム 歯科']
# ['韓国', '日本 韓国']
# ['韓国', 'アプリ 韓国人']
# ['韓国', '矯正歯科 日本語']
# ['韓国', '通話 アプリ']
# ['韓国', '動画 通話']
# ['韓国', '矯正歯科 ホワイト']
# ['韓国', '治療 丁寧']
# ['韓国', 'アンケート 回答']
# ['韓国', '近く ホワイト']
# ['韓国', '歯科 サムスン']
# ['韓国', 'ドリーム 歯科']
# ['韓国', '韓国 在住']
# ['韓国', '韓国 韓国語']
# ['シンガポール', '日本語 教師']
# ['シンガポール', '前髪 前髪']
# ['シンガポール', '日本 眼科 度数']
# ['シンガポール', '水野 敬也']
# ['シンガポール', 'オンライン 送金']
# ['シンガポール', '小児科 先生']
# ['シンガポール', '日本人 コンド']
# ['シンガポール', '病院 病院']
# ['シンガポール', 'ペット ホテル']
# ['シンガポール', '他 先生']
# ['シンガポール', '販売所 ネット カンボジア']
# ['シンガポール', '現地 採用']
# ['シンガポール', '丁寧 先生']
# ['シンガポール', '多い 日本']
# ['シンガポール', '窓 レバー']
# ['シンガポール', 'お店 お店']
# ['シンガポール', 'アンケート 調査']
# ['シンガポール', '場合 用途 朝夕']
# ['シンガポール', 'メイド 日系']
# ['シンガポール', 'サロン 自然']
# ['シンガポール', 'ドラム 式']
# ['シンガポール', '日本 際']
# ['シンガポール', 'カンボジア 法 規制']
# ['シンガポール', 'ホワイト ドリーム 歯科']
# ['シンガポール', '日本 韓国']
# ['シンガポール', '感染 状況']
# ['シンガポール', 'ローカル 日本語']
# ['シンガポール', '場所 現地']
# ['シンガポール', '主人 シンガポール']
# ['シンガポール', 'シンガポール 在住']
# ['シンガポール', '日本人 会']
# ['シンガポール', '小児科 他']
# ['シンガポール', '眼科 度数 販売所']
# ['シンガポール', 'ネット カンボジア']
# ['シンガポール', '動画 通話']
# ['シンガポール', 'タバコ 部屋']
# ['シンガポール', '治療 丁寧']
# ['シンガポール', '病院 ペット']
# ['シンガポール', 'カンボジア 法']
# ['シンガポール', '先生 お気に入り']
# ['シンガポール', '家族 日本人']
# ['シンガポール', '事 子猫']
# ['シンガポール', '入金 可能']
# ['シンガポール', '韓国 韓国語']
# ['シンガポール', '日本 企業']
# ['シンガポール', '婚約指輪 サイズ']
# ['シンガポール', '先生 病院']
# ['シンガポール', '学費 補助']
# ['シンガポール', '場所 ご存知']
# ['シンガポール', 'ローカル 病院']
# ['シンガポール', '実費 保険']
# ['シンガポール', '子猫 狂犬病']
# ['シンガポール', '嬉しい シンガポール']
# ['シンガポール', 'タバコ 方法']
# ['シンガポール', '実際 小児科']
# ['シンガポール', 'シンガポール 日本人']
# ['シンガポール', '日本語 漫画']
# ['シンガポール', '韓国人 女性']
# ['シンガポール', '日本 予定']
# ['シンガポール', 'シンガポール 日本']
# ['シンガポール', '係留 施設']
# ['シンガポール', '患者 電話番号']
# ['シンガポール', '韓国語 オススメ']
# ['シンガポール', '歯科 通訳']
# ['シンガポール', 'ホワイト ドリーム']
# ['シンガポール', 'ご存知 日系']
# ['シンガポール', 'ベッドルーム メイド']
# ['シンガポール', '洗濯機 コンド']
# ['シンガポール', '旅行 予定']
# ['シンガポール', 'プノンペン 運転 手車']
# ['シンガポール', '用途 朝夕 通勤']
# ['シンガポール', '度数 販売所']
# ['シンガポール', '洗濯機 掃除']
# ['シンガポール', 'おすすめ サロン']
# ['シンガポール', '通話 アプリ']
# ['シンガポール', '用途 朝夕']
# ['シンガポール', 'コロナ 影響']
# ['シンガポール', '電話番号 実際']
# ['シンガポール', '手車 場合 用途']
# ['シンガポール', 'お気に入り 患者']
# ['シンガポール', '情報 シンガポール']
# ['シンガポール', '情報 嬉しい']
# ['シンガポール', '者 ご存知']
# ['シンガポール', '学校 学校']
# ['シンガポール', 'シンガポール 美容室']
# ['シンガポール', '運転 手車']
# ['シンガポール', 'トランジット エリア']
# ['シンガポール', 'シンガポール インターンシップ']
# ['シンガポール', 'シンガポール マレーシア']
# ['シンガポール', '丁寧 いつも']
# ['シンガポール', '経験 メイド']
# ['シンガポール', 'カンボジアコンタクトレンズ 日本']
# ['シンガポール', '在住 日本人']
# ['シンガポール', '法 規制']
# ['シンガポール', '式 洗濯機']
# ['シンガポール', 'すすめ 情報']
# ['シンガポール', '眼科 度数']
# ['シンガポール', '予定 お店']
# ['シンガポール', '予定 コンド']
# ['シンガポール', 'エリア 両替']
# ['シンガポール', 'ローカル 美容院']
# ['シンガポール', '施設 シンガポール']
# ['シンガポール', 'インターンシップ 企業']
# ['シンガポール', '業 者']
# ['シンガポール', '可能 銀行']
# ['シンガポール', '矯正 丁寧']
# ['シンガポール', '高い シンガポール']
# ['シンガポール', 'マレーシア 旅行']
# ['シンガポール', 'お店 ご存知']
# ['シンガポール', '良かっ 情報']
# ['シンガポール', '日焼け 防止']
# ['シンガポール', '掃除 洗剤']
# ['シンガポール', '日系 サロン']
# ['シンガポール', '里親 コンドミニアム']
# ['シンガポール', '兄弟 里親']
# ['シンガポール', '必要 シンガポール']
# ['シンガポール', 'コンド コンド']
# ['シンガポール', '直し お店']
# ['シンガポール', '企業 サービス']
# ['シンガポール', '運転 手車 場合']
# ['シンガポール', '朝夕 通勤 片道']
# ['シンガポール', '日本 眼科']
# ['シンガポール', 'シンガポール 英語']
# ['シンガポール', '小学校 学費']
# ['シンガポール', '日本人 小学校']
# ['シンガポール', 'アプリ 韓国人']
# ['シンガポール', '矯正歯科 日本語']
# ['シンガポール', '日系 ローカル']
# ['シンガポール', 'エリア 場所']
# ['シンガポール', '病院 ラッフルズ']
# ['シンガポール', '矯正歯科 ホワイト']
# ['シンガポール', '狂犬病 期間']
# ['シンガポール', '歯科 サムスン']
# ['シンガポール', '韓国 在住']
# ['シンガポール', '既婚 友達']
# ['シンガポール', '日本人 学生']
# ['シンガポール', '歯科 矯正歯科']
# ['シンガポール', '日本 チャンギ']
# ['シンガポール', '販売所 ネット']
# ['シンガポール', '家具 家電']
# ['シンガポール', '一緒 里親']
# ['シンガポール', '日本 シンガポール']
# ['シンガポール', '良い 矯正歯科']
# ['シンガポール', '度数 販売所 ネット']
# ['シンガポール', '通勤 片道 カンボジアコンタクトレンズ']
# ['シンガポール', 'ローカル 日系']
# ['シンガポール', '江南駅 近く']
# ['シンガポール', 'ご存知 嬉しい']
# ['シンガポール', '日本 事']
# ['シンガポール', 'お店 家具']
# ['シンガポール', 'コンド 備え付け']
# ['シンガポール', '狂犬病 注射']
# ['シンガポール', '韓国語 初心者']
# ['シンガポール', '日本人 ワークパーミッド']
# ['シンガポール', '朝夕 通勤']
# ['シンガポール', '在住 日本']
# ['シンガポール', '英語 教育']
# ['シンガポール', 'ローカル 予定']
# ['シンガポール', '木下 グループ']
# ['シンガポール', '手車 場合']
# ['シンガポール', 'マンスリー マンション']
# ['シンガポール', 'アンケート 回答']
# ['シンガポール', '野菜 料理']
# ['シンガポール', '近く ホワイト']
# ['シンガポール', '送金 操作']
# ['シンガポール', 'ドリーム 歯科']
# ['シンガポール', 'クレジットカード 会社']
# ['シンガポール', '通勤 片道']
# ['シンガポール', '喫煙者 タバコ']
# ['シンガポール', 'ご存知 ご存知']
# yake ['小児科 先生', '狂犬病 期間', '日本 事', '施設 シンガポール', '狂犬病 注射', '事 子猫', 'シンガポール 日本人', '実際 小児科', '先生 お気に入り', '小児科 他', '他 先生', '係留 施設', '先生 病院', '婚約指輪 サイズ', '経験 メイド', 'メイド 日系', '患者 電話番号', 'ベッドルーム メイド', '子猫 狂犬病', '一緒 里親', 'シンガポール 美容室', '里親 コンドミニアム', '日本人 学生', '電話番号 実際', '兄弟 里親', '日本人 コンド', '家族 日本人', '高い シンガポール', '直し お店', 'お気に入り 患者']
# ['スペイン', '日本語 教師']
# ['スペイン', '前髪 前髪']
# ['スペイン', '日本 眼科 度数']
# ['スペイン', '水野 敬也']
# ['スペイン', 'オンライン 送金']
# ['スペイン', '小児科 先生']
# ['スペイン', '上巻 下巻']
# ['スペイン', '日本人 コンド']
# ['スペイン', '病院 病院']
# ['スペイン', 'ペット ホテル']
# ['スペイン', '他 先生']
# ['スペイン', '販売所 ネット カンボジア']
# ['スペイン', 'バレンシア 大学']
# ['スペイン', '現地 採用']
# ['スペイン', '日本食 レストラン']
# ['スペイン', '丁寧 先生']
# ['スペイン', '男性 次']
# ['スペイン', '多い 日本']
# ['スペイン', 'スペイン 旅行']
# ['スペイン', '窓 レバー']
# ['スペイン', 'センター タクシー']
# ['スペイン', 'お店 お店']
# ['スペイン', 'ためよう 情報']
# ['スペイン', 'アンケート 調査']
# ['スペイン', '場合 用途 朝夕']
# ['スペイン', 'バルセロナ 拠点']
# ['スペイン', 'メイド 日系']
# ['スペイン', 'サロン 自然']
# ['スペイン', 'ドラム 式']
# ['スペイン', '日本 際']
# ['スペイン', '連絡 フロント']
# ['スペイン', 'カンボジア 法 規制']
# ['スペイン', '日本人 美容師']
# ['スペイン', 'ホワイト ドリーム 歯科']
# ['スペイン', '日本 韓国']
# ['スペイン', '感染 状況']
# ['スペイン', 'ローカル 日本語']
# ['スペイン', '美味しい 料理']
# ['スペイン', '場所 現地']
# ['スペイン', '主人 シンガポール']
# ['スペイン', 'シンガポール 在住']
# ['スペイン', '日本人 会']
# ['スペイン', '携帯 会社']
# ['スペイン', '小児科 他']
# ['スペイン', '眼科 度数 販売所']
# ['スペイン', 'ネット カンボジア']
# ['スペイン', '動画 通話']
# ['スペイン', 'タバコ 部屋']
# ['スペイン', '場所 マドリード']
# ['スペイン', '会社 スペイン']
# ['スペイン', 'バルセロナ 旅行']
# ['スペイン', '治療 丁寧']
# ['スペイン', '病院 ペット']
# ['スペイン', '大学 外国人']
# ['スペイン', 'カンボジア 法']
# ['スペイン', '都市 更新']
# ['スペイン', '先生 お気に入り']
# ['スペイン', '家族 日本人']
# ['スペイン', '事 子猫']
# ['スペイン', '入金 可能']
# ['スペイン', '韓国 韓国語']
# ['スペイン', '日本 企業']
# ['スペイン', '宿 バルセロナ']
# ['スペイン', '婚約指輪 サイズ']
# ['スペイン', '先生 病院']
# ['スペイン', '学費 補助']
# ['スペイン', '子ども 小さい']
# ['スペイン', '場所 ご存知']
# ['スペイン', 'ローカル 病院']
# ['スペイン', '実費 保険']
# ['スペイン', '日本人 対象']
# ['スペイン', '子猫 狂犬病']
# ['スペイン', '嬉しい シンガポール']
# ['スペイン', 'タバコ 方法']
# ['スペイン', '実際 小児科']
# ['スペイン', 'シンガポール 日本人']
# ['スペイン', '日本語 漫画']
# ['スペイン', '韓国人 女性']
# ['スペイン', '日本 予定']
# ['スペイン', 'シンガポール 日本']
# ['スペイン', 'ありがたい 学生']
# ['スペイン', '係留 施設']
# ['スペイン', '患者 電話番号']
# ['スペイン', '韓国語 オススメ']
# ['スペイン', '歯科 通訳']
# ['スペイン', 'ホワイト ドリーム']
# ['スペイン', 'ご存知 日系']
# ['スペイン', 'ベッドルーム メイド']
# ['スペイン', 'カメラ セビリア']
# ['スペイン', '洗濯機 コンド']
# ['スペイン', '旅行 予定']
# ['スペイン', 'プノンペン 運転 手車']
# ['スペイン', '用途 朝夕 通勤']
# ['スペイン', '忘れ物 カメラ']
# ['スペイン', '度数 販売所']
# ['スペイン', '洗濯機 掃除']
# ['スペイン', 'おすすめ サロン']
# ['スペイン', '通話 アプリ']
# ['スペイン', '用途 朝夕']
# ['スペイン', 'コロナ 影響']
# ['スペイン', '電話番号 実際']
# ['スペイン', '手車 場合 用途']
# ['スペイン', 'お気に入り 患者']
# ['スペイン', '情報 シンガポール']
# ['スペイン', 'クリスマス 息子']
# ['スペイン', '情報 嬉しい']
# ['スペイン', '手探り 状態']
# ['スペイン', '者 ご存知']
# ['スペイン', '学校 学校']
# ['スペイン', '拠点 グラナダ']
# ['スペイン', 'シンガポール 美容室']
# ['スペイン', '運転 手車']
# ['スペイン', 'トランジット エリア']
# ['スペイン', 'シンガポール インターンシップ']
# ['スペイン', '在住 詳しい']
# ['スペイン', 'シンガポール マレーシア']
# ['スペイン', '丁寧 いつも']
# ['スペイン', '経験 メイド']
# ['スペイン', 'カンボジアコンタクトレンズ 日本']
# ['スペイン', '在住 日本人']
# ['スペイン', '法 規制']
# ['スペイン', '式 洗濯機']
# ['スペイン', 'すすめ 情報']
# ['スペイン', '眼科 度数']
# ['スペイン', '予定 お店']
# ['スペイン', '予定 コンド']
# ['スペイン', 'エリア 両替']
# ['スペイン', 'ローカル 美容院']
# ['スペイン', '施設 シンガポール']
# ['スペイン', 'インターンシップ 企業']
# ['スペイン', '業 者']
# ['スペイン', '日本人 友達']
# ['スペイン', 'ビザ 更新']
# ['スペイン', '可能 銀行']
# ['スペイン', '矯正 丁寧']
# ['スペイン', '高い シンガポール']
# ['スペイン', 'スペイン語 日常']
# ['スペイン', 'マレーシア 旅行']
# ['スペイン', 'お店 ご存知']
# ['スペイン', '良かっ 情報']
# ['スペイン', '日焼け 防止']
# ['スペイン', '掃除 洗剤']
# ['スペイン', '日系 サロン']
# ['スペイン', '里親 コンドミニアム']
# ['スペイン', '事 学生']
# ['スペイン', '場所 お勧め']
# ['スペイン', '母 家族']
# ['スペイン', '兄弟 里親']
# ['スペイン', '必要 シンガポール']
# ['スペイン', 'コンド コンド']
# ['スペイン', '直し お店']
# ['スペイン', '企業 サービス']
# ['スペイン', '赤川 次郎']
# ['スペイン', '運転 手車 場合']
# ['スペイン', '朝夕 通勤 片道']
# ['スペイン', '下巻 シドニー']
# ['スペイン', '日本 眼科']
# ['スペイン', '都市 都市']
# ['スペイン', 'シンガポール 英語']
# ['スペイン', '小学校 学費']
# ['スペイン', '家族 旅行']
# ['スペイン', '日本人 小学校']
# ['スペイン', 'アプリ 韓国人']
# ['スペイン', '矯正歯科 日本語']
# ['スペイン', '日系 ローカル']
# ['スペイン', '不安 都市間']
# ['スペイン', 'エリア 場所']
# ['スペイン', '病院 ラッフルズ']
# ['スペイン', '矯正歯科 ホワイト']
# ['スペイン', '情報 交換']
# ['スペイン', '狂犬病 期間']
# ['スペイン', '育児 情報']
# ['スペイン', '歯科 サムスン']
# ['スペイン', '日本 スペイン']
# ['スペイン', '韓国 在住']
# ['スペイン', '既婚 友達']
# ['スペイン', '日本人 学生']
# ['スペイン', '歯科 矯正歯科']
# ['スペイン', 'シドニー シェルダン']
# ['スペイン', '日本 チャンギ']
# ['スペイン', '販売所 ネット']
# ['スペイン', '家具 家電']
# ['スペイン', '一緒 里親']
# ['スペイン', '予定 育児']
# ['スペイン', '日本 シンガポール']
# ['スペイン', '良い 矯正歯科']
# ['スペイン', '度数 販売所 ネット']
# ['スペイン', '通勤 片道 カンボジアコンタクトレンズ']
# ['スペイン', 'ローカル 日系']
# ['スペイン', '江南駅 近く']
# ['スペイン', 'ご存知 嬉しい']
# ['スペイン', '日本 事']
# ['スペイン', '学校 学生']
# ['スペイン', '海外 美容師']
# ['スペイン', '再生 方法']
# ['スペイン', '都市 学生']
# ['スペイン', 'お店 家具']
# ['スペイン', 'コンド 備え付け']
# ['スペイン', '語学 学校']
# ['スペイン', '狂犬病 注射']
# ['スペイン', '韓国語 初心者']
# ['スペイン', '方法 宿']
# ['スペイン', '日本人 ワークパーミッド']
# ['スペイン', '朝夕 通勤']
# ['スペイン', '在住 日本']
# ['スペイン', 'サイト 近所']
# ['スペイン', 'アメリカ人 ためよう']
# ['スペイン', '英語 教育']
# ['スペイン', 'ローカル 予定']
# ['スペイン', '木下 グループ']
# ['スペイン', '都市間 移動']
# ['スペイン', 'フロント 係']
# ['スペイン', '手車 場合']
# ['スペイン', 'マンスリー マンション']
# ['スペイン', 'アンケート 回答']
# ['スペイン', '野菜 料理']
# ['スペイン', 'グラナダ 子ども']
# ['スペイン', '日本 荷物']
# ['スペイン', '近く ホワイト']
# ['スペイン', '送金 操作']
# ['スペイン', '予定 バルセロナ']
# ['スペイン', '交換 サイト']
# ['スペイン', 'ドリーム 歯科']
# ['スペイン', 'クレジットカード 会社']
# ['スペイン', '通勤 片道']
# ['スペイン', '移動 子連れ']
# ['スペイン', '喫煙者 タバコ']
# ['スペイン', '学生 ビザ']
# ['スペイン', 'ご存知 ご存知']
# yake ['クリスマス 息子', '子ども 小さい', 'グラナダ 子ども', '手探り 状態', '拠点 グラナダ', '宿 バルセロナ', 'カメラ セビリア', 'バルセロナ 拠点', 'サイト 近所', 'ためよう 情報', '都市間 移動', '移動 子連れ', '美味しい 料理', '不安 都市間', '母 家族', '方法 宿', '連絡 フロント', '交換 サイト', '男性 次', '携帯 会社', '予定 バルセロナ', '忘れ物 カメラ', 'アメリカ人 ためよう', '会社 スペイン', '育児 情報', '情報 交換', '旅行 予定', '家族 旅行', '予定 育児', 'フロント 係']
# ['タイ', '日本語 教師']
# ['タイ', '小児科 先生']
# ['タイ', '上巻 下巻']
# ['タイ', '日本人 コンド']
# ['タイ', '日常 会話']
# ['タイ', 'バンコク バンコク']
# ['タイ', '金 所']
# ['タイ', '大きい サイズ']
# ['タイ', 'アンケート 調査']
# ['タイ', '教室 ご存知']
# ['タイ', '場合 用途 朝夕']
# ['タイ', '情報 タイ']
# ['タイ', '仕事 都合']
# ['タイ', 'バンコク 在住']
# ['タイ', 'ホワイト ドリーム 歯科']
# ['タイ', '皆 病院']
# ['タイ', '日本人 女性']
# ['タイ', '主人 シンガポール']
# ['タイ', '保健所 窓口']
# ['タイ', '所 事情']
# ['タイ', '動画 通話']
# ['タイ', '場所 マドリード']
# ['タイ', '会社 スペイン']
# ['タイ', '病院 ペット']
# ['タイ', '前 人間']
# ['タイ', '事 要件']
# ['タイ', '埼玉県草加市 八潮市']
# ['タイ', '韓国 韓国語']
# ['タイ', 'カード カード']
# ['タイ', '場所 ご存知']
# ['タイ', '実費 保険']
# ['タイ', '子猫 狂犬病']
# ['タイ', '韓国人 女性']
# ['タイ', 'ありがたい 学生']
# ['タイ', 'ピアノ ピアノ']
# ['タイ', '韓国語 オススメ']
# ['タイ', 'ホワイト ドリーム']
# ['タイ', '洗濯機 コンド']
# ['タイ', '旅行 予定']
# ['タイ', '銀行 タイ']
# ['タイ', 'サッカー スクール']
# ['タイ', '病気 髪の毛']
# ['タイ', '事 日本']
# ['タイ', 'ペット 一緒']
# ['タイ', '日本テレビ 番組']
# ['タイ', '電話番号 実際']
# ['タイ', '手車 場合 用途']
# ['タイ', '情報 シンガポール']
# ['タイ', '時間帯 混雑']
# ['タイ', '正 社員']
# ['タイ', '学校 学校']
# ['タイ', '自分 台湾']
# ['タイ', 'タイ 教育']
# ['タイ', '法 規制']
# ['タイ', '予定 コンド']
# ['タイ', 'ビザ 就労']
# ['タイ', 'ヨーグルト ユニセックス']
# ['タイ', '屋内 遊び場']
# ['タイ', 'インターンシップ 企業']
# ['タイ', '生活 プレーヤー']
# ['タイ', '日本人 友達']
# ['タイ', '英語 タイ']
# ['タイ', '健康 診断書']
# ['タイ', '安定性 サーバー']
# ['タイ', '里親 コンドミニアム']
# ['タイ', '窓口 中国人']
# ['タイ', '母 家族']
# ['タイ', 'コンド コンド']
# ['タイ', '下巻 シドニー']
# ['タイ', '都市 都市']
# ['タイ', 'コロナ 禍']
# ['タイ', 'タイシルクシンプルシルク 下着']
# ['タイ', '記事 記事']
# ['タイ', 'エリア 場所']
# ['タイ', '病院 ラッフルズ']
# ['タイ', 'バンコク 市']
# ['タイ', '狂犬病 期間']
# ['タイ', '勧め 歯医者']
# ['タイ', '歯科 サムスン']
# ['タイ', '成田 係員']
# ['タイ', 'お店 バンコク']
# ['タイ', 'シドニー シェルダン']
# ['タイ', '高額 修繕費']
# ['タイ', '家具 家電']
# ['タイ', '通勤 片道 カンボジアコンタクトレンズ']
# ['タイ', '日本 事']
# ['タイ', 'ウェイパー 調味料']
# ['タイ', '以下 除湿器']
# ['タイ', '都市 学生']
# ['タイ', 'お店 ネット']
# ['タイ', '中国人 上司']
# ['タイ', '方法 宿']
# ['タイ', 'ニューハーフカツラ 問屋街']
# ['タイ', 'ヘアカット 専門店']
# ['タイ', 'サイト 近所']
# ['タイ', 'ビザタイ 人材紹介']
# ['タイ', '木下 グループ']
# ['タイ', '料理 タイ']
# ['タイ', '会社 日本人']
# ['タイ', 'バンコク 病院']
# ['タイ', '歯科 医院']
# ['タイ', '八潮市 カット']
# ['タイ', '画面 方法']
# ['タイ', '予定 バルセロナ']
# ['タイ', 'タイ 物']
# ['タイ', '作り方 分量']
# ['タイ', '日本 眼科 度数']
# ['タイ', '就労 質問']
# ['タイ', 'センター カウンター']
# ['タイ', '語 お仕事']
# ['タイ', '他 先生']
# ['タイ', '髪の毛 友達']
# ['タイ', '丁寧 先生']
# ['タイ', 'お店 お店']
# ['タイ', 'ためよう 情報']
# ['タイ', 'セグメント ネット']
# ['タイ', '主人 バンコク']
# ['タイ', 'サロン 自然']
# ['タイ', '学校 現金']
# ['タイ', '言いがかり デポジット']
# ['タイ', '係員 中国人']
# ['タイ', '場所 現地']
# ['タイ', '案内 中国人']
# ['タイ', '語 英語']
# ['タイ', '要件 許可']
# ['タイ', 'バルセロナ 旅行']
# ['タイ', '大学 外国人']
# ['タイ', 'カンボジア 法']
# ['タイ', '先生 お気に入り']
# ['タイ', '家族 日本人']
# ['タイ', '入金 可能']
# ['タイ', '日本 企業']
# ['タイ', '楽しく バンコク']
# ['タイ', '宿 バルセロナ']
# ['タイ', '観光 ビザ']
# ['タイ', '航空会社 コールセンター']
# ['タイ', '先生 病院']
# ['タイ', '学費 補助']
# ['タイ', 'おすすめ ホテル']
# ['タイ', '嬉しい シンガポール']
# ['タイ', '実際 小児科']
# ['タイ', 'バンコク ペット']
# ['タイ', '幼稚園 送迎']
# ['タイ', 'ユニセックス ヘアカット']
# ['タイ', 'アドバイス 幼稚園']
# ['タイ', '混雑 状況']
# ['タイ', '質問 バンコク']
# ['タイ', 'バンコク 日本人']
# ['タイ', '用途 朝夕 通勤']
# ['タイ', '学校 ご存知']
# ['タイ', '医療 場合']
# ['タイ', 'ビザ 取得']
# ['タイ', '友達 場所']
# ['タイ', '物件 自分']
# ['タイ', '情報 嬉しい']
# ['タイ', '手探り 状態']
# ['タイ', '者 ご存知']
# ['タイ', '拠点 グラナダ']
# ['タイ', 'アクセス よい']
# ['タイ', 'タイ 語']
# ['タイ', 'タイ 日本']
# ['タイ', '自分 現地']
# ['タイ', 'シンガポール マレーシア']
# ['タイ', '丁寧 いつも']
# ['タイ', 'カンボジアコンタクトレンズ 日本']
# ['タイ', '妻 生活']
# ['タイ', '東京都 係員']
# ['タイ', '眼科 度数']
# ['タイ', '特別 観光']
# ['タイ', '外出 禁止']
# ['タイ', 'バンコク 良い']
# ['タイ', 'オンライン ショップ']
# ['タイ', '可能 銀行']
# ['タイ', '場合 風呂']
# ['タイ', 'スペイン語 日常']
# ['タイ', '際 手続き']
# ['タイ', '分量 製品']
# ['タイ', '外国人 不法']
# ['タイ', '日本 プライム']
# ['タイ', '場所 子連れ']
# ['タイ', 'インター 幼稚園']
# ['タイ', '企業 サービス']
# ['タイ', '頭 古い']
# ['タイ', '小学校 学費']
# ['タイ', '実際 ビザ']
# ['タイ', '英語 オンライン']
# ['タイ', '半年 契約社員']
# ['タイ', '他 会場']
# ['タイ', 'お店 情報']
# ['タイ', '日本 スペイン']
# ['タイ', '韓国 在住']
# ['タイ', '既婚 友達']
# ['タイ', '英語 中国語']
# ['タイ', '幼稚園 対策']
# ['タイ', '店舗 店舗']
# ['タイ', '一緒 里親']
# ['タイ', 'クリンスイ 普通']
# ['タイ', '予定 育児']
# ['タイ', '日本 タイ']
# ['タイ', 'タイ 皆']
# ['タイ', 'スクンビット 近辺']
# ['タイ', 'みな 対策']
# ['タイ', '一般的 次']
# ['タイ', 'ローカル 日系']
# ['タイ', '江南駅 近く']
# ['タイ', 'アヤ 退職金']
# ['タイ', 'ご存知 嬉しい']
# ['タイ', '海外 美容師']
# ['タイ', 'バンコクファイヤスティックファイヤ 日本']
# ['タイ', '実 友人']
# ['タイ', '分 サービス料']
# ['タイ', '狂犬病 注射']
# ['タイ', '日本人 インド人']
# ['タイ', '最低 事']
# ['タイ', '日本人 ワークパーミッド']
# ['タイ', '中国人 日本人']
# ['タイ', '朝夕 通勤']
# ['タイ', 'アメリカ人 ためよう']
# ['タイ', 'お金 必要']
# ['タイ', '係員 ワクチン']
# ['タイ', '指導 中学生']
# ['タイ', '記事 お店']
# ['タイ', '都市間 移動']
# ['タイ', '医院 個人']
# ['タイ', '朝 夕方']
# ['タイ', '子供 用品']
# ['タイ', 'グラナダ 子ども']
# ['タイ', '日本 荷物']
# ['タイ', '近く ホワイト']
# ['タイ', 'ドリーム 歯科']
# ['タイ', 'バンコク 生活']
# ['タイ', '前髪 前髪']
# ['タイ', 'オンライン 送金']
# ['タイ', '水野 敬也']
# ['タイ', 'プレーヤー 欲しい']
# ['タイ', '名前 お店']
# ['タイ', 'クッキング 教室']
# ['タイ', '歯ブラシ セット']
# ['タイ', 'バレンシア 大学']
# ['タイ', '男性 次']
# ['タイ', '多い 日本']
# ['タイ', 'スペイン 旅行']
# ['タイ', '際 関税']
# ['タイ', 'ご存知 詳細']
# ['タイ', '半袖 ジャケット']
# ['タイ', 'アニメ 英語']
# ['タイ', '医院 今ひとつ']
# ['タイ', '方法 ご存知']
# ['タイ', '日本 際']
# ['タイ', 'カンボジア 法 規制']
# ['タイ', 'ドイツ人 学校']
# ['タイ', '近郊 施設']
# ['タイ', '感染 状況']
# ['タイ', 'ローカル 日本語']
# ['タイ', '新生児 ミルク']
# ['タイ', 'シンガポール 在住']
# ['タイ', '携帯 会社']
# ['タイ', '小児科 他']
# ['タイ', 'タバコ 部屋']
# ['タイ', '場所 情報']
# ['タイ', '都市 更新']
# ['タイ', 'サイド スポイラー']
# ['タイ', '英語 対応']
# ['タイ', 'バンコク 旅行']
# ['タイ', '日本人 自分']
# ['タイ', 'カード 特典']
# ['タイ', 'オーナー 高額']
# ['タイ', 'ラビット カード']
# ['タイ', '保育園 幼稚園']
# ['タイ', '中学生 教育費']
# ['タイ', 'カット タイム']
# ['タイ', '子ども 小さい']
# ['タイ', '警察 レポート']
# ['タイ', 'ローカル 病院']
# ['タイ', '日本人 対象']
# ['タイ', 'ご存知 バンコク']
# ['タイ', '中国人 上司 中国人']
# ['タイ', 'シンガポール 日本人']
# ['タイ', '日本 予定']
# ['タイ', '係留 施設']
# ['タイ', '歯科 通訳']
# ['タイ', 'タイ 料理']
# ['タイ', '友達 友達']
# ['タイ', 'カメラ セビリア']
# ['タイ', '電子 ピアノ']
# ['タイ', 'デポジット 返金']
# ['タイ', '他 友達']
# ['タイ', 'おすすめ サロン']
# ['タイ', '用途 朝夕']
# ['タイ', '味覇 ウェイパー']
# ['タイ', 'ミルク 作り方']
# ['タイ', '江東区 保健所']
# ['タイ', '返答 修繕費']
# ['タイ', 'シンガポール 美容室']
# ['タイ', '運転 手車']
# ['タイ', '仕方 ビザタイ']
# ['タイ', '在住 日本人']
# ['タイ', '式 洗濯機']
# ['タイ', 'すすめ 情報']
# ['タイ', '本 際']
# ['タイ', 'ローカル 美容院']
# ['タイ', '者 クリンスイ']
# ['タイ', '語 検定']
# ['タイ', '業 者']
# ['タイ', '矯正 丁寧']
# ['タイ', 'プライム ビデオ']
# ['タイ', 'お店 ご存知']
# ['タイ', '掃除 洗剤']
# ['タイ', '場所 お勧め']
# ['タイ', '許可 最低']
# ['タイ', '修繕費 明細']
# ['タイ', '兄弟 里親']
# ['タイ', '以内 デポジット']
# ['タイ', '直し お店']
# ['タイ', 'クリンスイ 異常']
# ['タイ', '修繕費 デポジット']
# ['タイ', '日本 眼科']
# ['タイ', '子ども クッキング']
# ['タイ', 'シンガポール 英語']
# ['タイ', '日本人 小学校']
# ['タイ', 'スカイスパプールイメージドンピシャバンコク 近郊']
# ['タイ', '日本人 スタッフ']
# ['タイ', '日系 スーパー']
# ['タイ', '情報 交換']
# ['タイ', '日系 幼稚園']
# ['タイ', '詳細 パタヤ']
# ['タイ', '矯正 クリニック']
# ['タイ', '育児 情報']
# ['タイ', '皆 タイ']
# ['タイ', '値段 高く']
# ['タイ', '日本 チャンギ']
# ['タイ', '販売所 ネット']
# ['タイ', '方法 方法']
# ['タイ', '日本 シンガポール']
# ['タイ', '自分 場合']
# ['タイ', '再生 方法']
# ['タイ', '語学 学校']
# ['タイ', '看護師 介護士']
# ['タイ', '韓国語 初心者']
# ['タイ', 'スクンビット 界隈']
# ['タイ', '情報 近い']
# ['タイ', '女性 病気']
# ['タイ', '在住 日本']
# ['タイ', '市 ニューハーフカツラ']
# ['タイ', 'タイトル 疑問']
# ['タイ', 'タイ 病院']
# ['タイ', 'フロント 係']
# ['タイ', 'タイ 女性']
# ['タイ', 'マンスリー マンション']
# ['タイ', 'アンケート 回答']
# ['タイ', '野菜 料理']
# ['タイ', '友人 女性']
# ['タイ', '送金 操作']
# ['タイ', '通勤 片道']
# ['タイ', '移動 子連れ']
# ['タイ', '工場 詳しい']
# ['タイ', 'ご存知 ご存知']
# ['タイ', '台湾 後半']
# ['タイ', '情報 埼玉県草加市']
# ['タイ', '家族 ビザ']
# ['タイ', 'タイ 現地']
# ['タイ', '病院 病院']
# ['タイ', 'ペット ホテル']
# ['タイ', '販売所 ネット カンボジア']
# ['タイ', 'バンコク 電子']
# ['タイ', '現地 採用']
# ['タイ', '日本食 レストラン']
# ['タイ', 'アソーク 近辺']
# ['タイ', '窓 レバー']
# ['タイ', 'センター タクシー']
# ['タイ', '係員 中国人 上司']
# ['タイ', 'バルセロナ 拠点']
# ['タイ', 'メイド 日系']
# ['タイ', '水 情報']
# ['タイ', 'ドラム 式']
# ['タイ', '連絡 フロント']
# ['タイ', '学校 診断書']
# ['タイ', '日本人 美容師']
# ['タイ', 'タイ 日本人']
# ['タイ', '日本 韓国']
# ['タイ', '無理 実際']
# ['タイ', '際 バンコク']
# ['タイ', '美味しい 料理']
# ['タイ', '日本人 会']
# ['タイ', '仲介料 自分']
# ['タイ', '次 勤務先']
# ['タイ', '眼科 度数 販売所']
# ['タイ', 'ネット カンボジア']
# ['タイ', '事情 お金']
# ['タイ', '治療 丁寧']
# ['タイ', '安い ベット']
# ['タイ', 'サーバー 会社']
# ['タイ', 'クリンスイ 浄水器']
# ['タイ', '事 子猫']
# ['タイ', '返金 中旬']
# ['タイ', '歯科 治療']
# ['タイ', '日本 運転免許証']
# ['タイ', '婚約指輪 サイズ']
# ['タイ', '所 ご存知']
# ['タイ', '人材紹介 オフィス']
# ['タイ', 'タバコ 方法']
# ['タイ', '送迎 会社']
# ['タイ', '日本語 漫画']
# ['タイ', '調味料 ご存知']
# ['タイ', 'タイム ヨーグルト']
# ['タイ', '詳細 高額']
# ['タイ', 'バンコク 銀行']
# ['タイ', 'シンガポール 日本']
# ['タイ', '患者 電話番号']
# ['タイ', '自分 可能']
# ['タイ', 'ご存知 日系']
# ['タイ', 'ベッドルーム メイド']
# ['タイ', 'ご存知 バンコクファイヤスティックファイヤ']
# ['タイ', '返金 契約書']
# ['タイ', 'プノンペン 運転 手車']
# ['タイ', '日本人 女']
# ['タイ', '排水 管']
# ['タイ', '忘れ物 カメラ']
# ['タイ', 'コンドミニアム 担保']
# ['タイ', '皆 会社']
# ['タイ', '英語 学校']
# ['タイ', '度数 販売所']
# ['タイ', '洗濯機 掃除']
# ['タイ', '基本料金 ボッタクリ']
# ['タイ', '幼稚園 入園']
# ['タイ', '通話 アプリ']
# ['タイ', '皆 バンコク']
# ['タイ', 'コロナ 影響']
# ['タイ', '問題 サーバー']
# ['タイ', 'お気に入り 患者']
# ['タイ', '東京都 係員 中国人']
# ['タイ', 'クリスマス 息子']
# ['タイ', '変圧器 日本']
# ['タイ', '浄水器 予定']
# ['タイ', '銀行 通帳']
# ['タイ', 'トランジット エリア']
# ['タイ', 'お店 タイ']
# ['タイ', 'シンガポール インターンシップ']
# ['タイ', '去勢 性格']
# ['タイ', '友達 娘']
# ['タイ', 'バンコク 日系']
# ['タイ', '単車 無理']
# ['タイ', '在住 詳しい']
# ['タイ', '経験 メイド']
# ['タイ', '予定 お店']
# ['タイ', 'エリア 両替']
# ['タイ', '中国人 武蔵野市']
# ['タイ', '施設 シンガポール']
# ['タイ', 'サーバー 側']
# ['タイ', 'ビザ 更新']
# ['タイ', '高い シンガポール']
# ['タイ', '娘 ピアノ']
# ['タイ', 'マレーシア 旅行']
# ['タイ', '良かっ 情報']
# ['タイ', '日焼け 防止']
# ['タイ', '日系 サロン']
# ['タイ', '事 学生']
# ['タイ', '思い出 佐賀']
# ['タイ', '必要 シンガポール']
# ['タイ', '赤川 次郎']
# ['タイ', '運転 手車 場合']
# ['タイ', '朝夕 通勤 片道']
# ['タイ', '治療 保険']
# ['タイ', '家族 旅行']
# ['タイ', '日系 ローカル']
# ['タイ', 'アプリ 韓国人']
# ['タイ', '矯正歯科 日本語']
# ['タイ', 'カッコ 必要']
# ['タイ', '不安 都市間']
# ['タイ', '矯正歯科 ホワイト']
# ['タイ', '郵便局 郵便局']
# ['タイ', '単車 アブナイ']
# ['タイ', '方々 意見']
# ['タイ', '返金 無し']
# ['タイ', '日本人 学生']
# ['タイ', '歯科 矯正歯科']
# ['タイ', '美味しい 和食']
# ['タイ', '意見 車']
# ['タイ', '良い 矯正歯科']
# ['タイ', '度数 販売所 ネット']
# ['タイ', '同時 配信']
# ['タイ', 'お店 トンロー']
# ['タイ', '音楽 スタジオ']
# ['タイ', '子供 他']
# ['タイ', '学校 学生']
# ['タイ', '下着 日本']
# ['タイ', 'お店 家具']
# ['タイ', 'コンド 備え付け']
# ['タイ', 'バンコク お店']
# ['タイ', '新生児 持ち運び']
# ['タイ', 'タイ 海外']
# ['タイ', '英語 教育']
# ['タイ', 'ローカル 予定']
# ['タイ', '会社 ご存知']
# ['タイ', '隔離 期間']
# ['タイ', 'ネット サーバー']
# ['タイ', '手車 場合']
# ['タイ', '交換 サイト']
# ['タイ', 'クレジットカード 会社']
# ['タイ', '喫煙者 タバコ']
# ['タイ', '学生 ビザ']
# yake ['市 ニューハーフカツラ', 'ニューハーフカツラ 問屋街', '水 情報', '髪の毛 友達', 'バンコク 市', '実 友人', '友人 女性', '女性 病気', '病気 髪の毛', '友達 場所', '無理 実際', 'スカイスパプールイメージドンピシャバンコク 近郊', '場合 風呂', 'タイシルクシンプルシルク 下着', '実際 ビザ', '情報 近い', '近郊 施設', '頭 古い', '単車 無理', '場所 情報', '単車 アブナイ', 'アドバイス 幼稚園', '幼稚園 入園', 'お店 情報', 'みな 対策', '意見 車', '場所 子連れ', '医療 場合', '方々 意見', '下着 日本']
# ['台湾', '日本語 教師']
# ['台湾', '小児科 先生']
# ['台湾', '上巻 下巻']
# ['台湾', '日本人 コンド']
# ['台湾', '日常 会話']
# ['台湾', '娘 一緒']
# ['台湾', 'バンコク バンコク']
# ['台湾', '金 所']
# ['台湾', '大きい サイズ']
# ['台湾', '名前 年齢']
# ['台湾', 'アンケート 調査']
# ['台湾', '教室 ご存知']
# ['台湾', '場合 用途 朝夕']
# ['台湾', 'アルバイト 時給']
# ['台湾', '情報 タイ']
# ['台湾', '仕事 都合']
# ['台湾', 'バンコク 在住']
# ['台湾', 'ホワイト ドリーム 歯科']
# ['台湾', '皆 病院']
# ['台湾', '日本人 女性']
# ['台湾', '主人 シンガポール']
# ['台湾', '保健所 窓口']
# ['台湾', '所 事情']
# ['台湾', '大学 正規']
# ['台湾', '動画 通話']
# ['台湾', '場所 マドリード']
# ['台湾', '会社 スペイン']
# ['台湾', '病院 ペット']
# ['台湾', '前 人間']
# ['台湾', '必要 情報']
# ['台湾', '日本 子供']
# ['台湾', '市 お店']
# ['台湾', '事 要件']
# ['台湾', '埼玉県草加市 八潮市']
# ['台湾', '韓国 韓国語']
# ['台湾', 'カード カード']
# ['台湾', '台湾 名字']
# ['台湾', '場所 ご存知']
# ['台湾', '実費 保険']
# ['台湾', '子猫 狂犬病']
# ['台湾', '新北 市']
# ['台湾', '韓国人 女性']
# ['台湾', 'ありがたい 学生']
# ['台湾', 'ピアノ ピアノ']
# ['台湾', '韓国語 オススメ']
# ['台湾', 'ホワイト ドリーム']
# ['台湾', '場所 台北']
# ['台湾', '市 中国語']
# ['台湾', '情報 李']
# ['台湾', '幼稚園 日本人']
# ['台湾', '洗濯機 コンド']
# ['台湾', '旅行 予定']
# ['台湾', '銀行 タイ']
# ['台湾', 'サッカー スクール']
# ['台湾', '病気 髪の毛']
# ['台湾', '事 日本']
# ['台湾', 'ペット 一緒']
# ['台湾', '日本 住民票']
# ['台湾', '日本テレビ 番組']
# ['台湾', '子供 一緒']
# ['台湾', '電話番号 実際']
# ['台湾', '手車 場合 用途']
# ['台湾', '情報 シンガポール']
# ['台湾', '台湾 際']
# ['台湾', '時間帯 混雑']
# ['台湾', '正 社員']
# ['台湾', '学校 学校']
# ['台湾', '自分 台湾']
# ['台湾', 'タイ 教育']
# ['台湾', '日本語 中国語']
# ['台湾', '法 規制']
# ['台湾', '野菜 不足']
# ['台湾', '予定 コンド']
# ['台湾', 'ビザ 就労']
# ['台湾', 'ヨーグルト ユニセックス']
# ['台湾', 'ご存知 追記']
# ['台湾', '屋内 遊び場']
# ['台湾', 'インターンシップ 企業']
# ['台湾', '生活 プレーヤー']
# ['台湾', '日本人 友達']
# ['台湾', '英語 タイ']
# ['台湾', '健康 診断書']
# ['台湾', '安定性 サーバー']
# ['台湾', '里親 コンドミニアム']
# ['台湾', '窓口 中国人']
# ['台湾', '台湾 アルバイト']
# ['台湾', '母 家族']
# ['台湾', 'コンド コンド']
# ['台湾', '知り合い 台湾']
# ['台湾', '下巻 シドニー']
# ['台湾', '都市 都市']
# ['台湾', 'コロナ 禍']
# ['台湾', 'タイシルクシンプルシルク 下着']
# ['台湾', '記事 記事']
# ['台湾', 'エリア 場所']
# ['台湾', '病院 ラッフルズ']
# ['台湾', 'バンコク 市']
# ['台湾', '狂犬病 期間']
# ['台湾', '勧め 歯医者']
# ['台湾', '歯科 サムスン']
# ['台湾', '成田 係員']
# ['台湾', 'お店 バンコク']
# ['台湾', 'ワクチン 必要']
# ['台湾', 'シドニー シェルダン']
# ['台湾', '場所 中国語']
# ['台湾', '高額 修繕費']
# ['台湾', '家具 家電']
# ['台湾', '生 クリーム']
# ['台湾', '日本人 主婦']
# ['台湾', '台北 新北']
# ['台湾', '条件 台北']
# ['台湾', '通勤 片道 カンボジアコンタクトレンズ']
# ['台湾', '日本 幼稚園']
# ['台湾', '日本 事']
# ['台湾', 'ウェイパー 調味料']
# ['台湾', '外来 日本語']
# ['台湾', '以下 除湿器']
# ['台湾', '台湾 就労ビザ']
# ['台湾', '都市 学生']
# ['台湾', 'お店 ネット']
# ['台湾', '中国人 上司']
# ['台湾', '方法 宿']
# ['台湾', 'ニューハーフカツラ 問屋街']
# ['台湾', 'ヘアカット 専門店']
# ['台湾', 'サイト 近所']
# ['台湾', 'ビザタイ 人材紹介']
# ['台湾', '木下 グループ']
# ['台湾', '料理 タイ']
# ['台湾', '会社 日本人']
# ['台湾', 'バンコク 病院']
# ['台湾', '歯科 医院']
# ['台湾', '八潮市 カット']
# ['台湾', '画面 方法']
# ['台湾', '予定 バルセロナ']
# ['台湾', '台湾 日本']
# ['台湾', 'タイ 物']
# ['台湾', '作り方 分量']
# ['台湾', '台灣 ビザ']
# ['台湾', '日本 眼科 度数']
# ['台湾', '日本人 少ない']
# ['台湾', '就労 質問']
# ['台湾', 'センター カウンター']
# ['台湾', '語 お仕事']
# ['台湾', '他 先生']
# ['台湾', '髪の毛 友達']
# ['台湾', '台北 子供']
# ['台湾', '問題 台北']
# ['台湾', '丁寧 先生']
# ['台湾', 'お店 お店']
# ['台湾', 'ためよう 情報']
# ['台湾', 'セグメント ネット']
# ['台湾', '中原 大学']
# ['台湾', '主人 バンコク']
# ['台湾', 'サロン 自然']
# ['台湾', '語学 研修']
# ['台湾', '学校 現金']
# ['台湾', '言いがかり デポジット']
# ['台湾', '可能 台湾']
# ['台湾', '係員 中国人']
# ['台湾', '場所 現地']
# ['台湾', '案内 中国人']
# ['台湾', '国産 ワクチン']
# ['台湾', '病院 日本語']
# ['台湾', '語 英語']
# ['台湾', '要件 許可']
# ['台湾', 'バルセロナ 旅行']
# ['台湾', '大学 外国人']
# ['台湾', '幼稚園 台北']
# ['台湾', 'カンボジア 法']
# ['台湾', '先生 お気に入り']
# ['台湾', '家族 日本人']
# ['台湾', '動物 病院']
# ['台湾', '入金 可能']
# ['台湾', '日本 企業']
# ['台湾', '予定 中国語']
# ['台湾', '楽しく バンコク']
# ['台湾', '宿 バルセロナ']
# ['台湾', '観光 ビザ']
# ['台湾', '航空会社 コールセンター']
# ['台湾', '先生 病院']
# ['台湾', '学費 補助']
# ['台湾', 'おすすめ ホテル']
# ['台湾', '嬉しい シンガポール']
# ['台湾', '実際 小児科']
# ['台湾', '中国語 子供']
# ['台湾', 'バンコク ペット']
# ['台湾', '台北 掲示板']
# ['台湾', '幼稚園 送迎']
# ['台湾', 'ユニセックス ヘアカット']
# ['台湾', 'アドバイス 幼稚園']
# ['台湾', '混雑 状況']
# ['台湾', '質問 バンコク']
# ['台湾', '無い 場合']
# ['台湾', 'バンコク 日本人']
# ['台湾', '用途 朝夕 通勤']
# ['台湾', '学校 ご存知']
# ['台湾', '医療 場合']
# ['台湾', '日本 日本']
# ['台湾', 'レンジ 白米']
# ['台湾', 'ビザ 取得']
# ['台湾', '友達 場所']
# ['台湾', '物件 自分']
# ['台湾', '情報 嬉しい']
# ['台湾', '手探り 状態']
# ['台湾', '者 ご存知']
# ['台湾', '拠点 グラナダ']
# ['台湾', 'アクセス よい']
# ['台湾', '整体 治療']
# ['台湾', 'タイ 語']
# ['台湾', 'タイ 日本']
# ['台湾', '自分 現地']
# ['台湾', 'シンガポール マレーシア']
# ['台湾', '日本語 英語']
# ['台湾', '丁寧 いつも']
# ['台湾', 'カンボジアコンタクトレンズ 日本']
# ['台湾', '妻 生活']
# ['台湾', '東京都 係員']
# ['台湾', '眼科 度数']
# ['台湾', '台湾 友人']
# ['台湾', '特別 観光']
# ['台湾', '番組 テレビ']
# ['台湾', '外出 禁止']
# ['台湾', 'バンコク 良い']
# ['台湾', 'オンライン ショップ']
# ['台湾', '日本語 授業']
# ['台湾', '可能 銀行']
# ['台湾', '場合 風呂']
# ['台湾', 'スペイン語 日常']
# ['台湾', '家族 友人']
# ['台湾', '際 手続き']
# ['台湾', '分量 製品']
# ['台湾', '外国人 不法']
# ['台湾', '日本 プライム']
# ['台湾', '場所 子連れ']
# ['台湾', 'インター 幼稚園']
# ['台湾', 'コロナ ワクチン']
# ['台湾', '企業 サービス']
# ['台湾', '日本人 日本語']
# ['台湾', '頭 古い']
# ['台湾', '小学校 学費']
# ['台湾', '治療 病院']
# ['台湾', '実際 ビザ']
# ['台湾', '日本人 学校']
# ['台湾', '英語 オンライン']
# ['台湾', '中国語 幼稚園']
# ['台湾', '半年 契約社員']
# ['台湾', '他 会場']
# ['台湾', '台北 市']
# ['台湾', 'お店 情報']
# ['台湾', '日本 スペイン']
# ['台湾', '韓国 在住']
# ['台湾', '既婚 友達']
# ['台湾', '英語 中国語']
# ['台湾', 'スタッフ 条件']
# ['台湾', '幼稚園 対策']
# ['台湾', 'お店 台湾']
# ['台湾', '幼稚園 日本語']
# ['台湾', '店舗 店舗']
# ['台湾', '一緒 里親']
# ['台湾', 'クリンスイ 普通']
# ['台湾', '予定 育児']
# ['台湾', '日本 タイ']
# ['台湾', 'タイ 皆']
# ['台湾', 'スクンビット 近辺']
# ['台湾', 'みな 対策']
# ['台湾', '一般的 次']
# ['台湾', '幼稚園 英語']
# ['台湾', 'ローカル 日系']
# ['台湾', '江南駅 近く']
# ['台湾', 'アヤ 退職金']
# ['台湾', 'ご存知 嬉しい']
# ['台湾', '海外 美容師']
# ['台湾', 'バンコクファイヤスティックファイヤ 日本']
# ['台湾', 'ヨーロピアン スクール']
# ['台湾', '実 友人']
# ['台湾', '分 サービス料']
# ['台湾', '狂犬病 注射']
# ['台湾', '日本人 インド人']
# ['台湾', '最低 事']
# ['台湾', '日本人 ワークパーミッド']
# ['台湾', '中国人 日本人']
# ['台湾', '市 日本']
# ['台湾', '朝夕 通勤']
# ['台湾', 'アメリカ人 ためよう']
# ['台湾', 'お金 必要']
# ['台湾', '係員 ワクチン']
# ['台湾', '指導 中学生']
# ['台湾', '記事 お店']
# ['台湾', '台北 在住']
# ['台湾', 'お店 台北']
# ['台湾', '都市間 移動']
# ['台湾', '医院 個人']
# ['台湾', '朝 夕方']
# ['台湾', '子供 用品']
# ['台湾', 'グラナダ 子ども']
# ['台湾', '日本 荷物']
# ['台湾', '近く ホワイト']
# ['台湾', '子供 場所']
# ['台湾', 'ドリーム 歯科']
# ['台湾', 'バンコク 生活']
# ['台湾', '前髪 前髪']
# ['台湾', 'オンライン 送金']
# ['台湾', '水野 敬也']
# ['台湾', 'プレーヤー 欲しい']
# ['台湾', '名前 お店']
# ['台湾', 'クッキング 教室']
# ['台湾', '歯ブラシ セット']
# ['台湾', '着物 着物']
# ['台湾', 'バレンシア 大学']
# ['台湾', '予定 コロナ']
# ['台湾', '男性 次']
# ['台湾', '市 新米']
# ['台湾', '多い 日本']
# ['台湾', 'スペイン 旅行']
# ['台湾', '際 関税']
# ['台湾', '台北 現状']
# ['台湾', 'ご存知 詳細']
# ['台湾', '半袖 ジャケット']
# ['台湾', 'アニメ 英語']
# ['台湾', '医院 今ひとつ']
# ['台湾', '方法 ご存知']
# ['台湾', '市 幼稚園']
# ['台湾', '日本 際']
# ['台湾', 'カンボジア 法 規制']
# ['台湾', '市 日本人']
# ['台湾', 'ドイツ人 学校']
# ['台湾', '近郊 施設']
# ['台湾', '感染 状況']
# ['台湾', 'ローカル 日本語']
# ['台湾', '病院 ご存じ']
# ['台湾', '新生児 ミルク']
# ['台湾', 'シンガポール 在住']
# ['台湾', '携帯 会社']
# ['台湾', '小児科 他']
# ['台湾', 'タバコ 部屋']
# ['台湾', '場所 情報']
# ['台湾', '都市 更新']
# ['台湾', 'サイド スポイラー']
# ['台湾', '英語 対応']
# ['台湾', 'バンコク 旅行']
# ['台湾', '日本人 自分']
# ['台湾', 'カード 特典']
# ['台湾', 'オーナー 高額']
# ['台湾', 'ラビット カード']
# ['台湾', 'キッチン スペース']
# ['台湾', '必要 日本']
# ['台湾', '台北 観光']
# ['台湾', '保育園 幼稚園']
# ['台湾', '着物 帯']
# ['台湾', '中学生 教育費']
# ['台湾', 'カット タイム']
# ['台湾', '子ども 小さい']
# ['台湾', '警察 レポート']
# ['台湾', '気功 整体']
# ['台湾', 'ローカル 病院']
# ['台湾', '日本人 対象']
# ['台湾', 'ご存知 バンコク']
# ['台湾', '中国人 上司 中国人']
# ['台湾', 'シンガポール 日本人']
# ['台湾', '日本 予定']
# ['台湾', 'ご存知 日本']
# ['台湾', '係留 施設']
# ['台湾', '歯科 通訳']
# ['台湾', 'タイ 料理']
# ['台湾', '友達 友達']
# ['台湾', 'カメラ セビリア']
# ['台湾', '電子 ピアノ']
# ['台湾', 'デポジット 返金']
# ['台湾', '他 友達']
# ['台湾', 'おすすめ サロン']
# ['台湾', '用途 朝夕']
# ['台湾', '味覇 ウェイパー']
# ['台湾', 'ミルク 作り方']
# ['台湾', '江東区 保健所']
# ['台湾', '多い 気']
# ['台湾', '返答 修繕費']
# ['台湾', '台湾 予定']
# ['台湾', '学校 中国語']
# ['台湾', 'シンガポール 美容室']
# ['台湾', '運転 手車']
# ['台湾', '仕方 ビザタイ']
# ['台湾', '在住 日本人']
# ['台湾', '式 洗濯機']
# ['台湾', 'すすめ 情報']
# ['台湾', '本 際']
# ['台湾', 'ローカル 美容院']
# ['台湾', '者 クリンスイ']
# ['台湾', '語 検定']
# ['台湾', '業 者']
# ['台湾', '矯正 丁寧']
# ['台湾', 'プライム ビデオ']
# ['台湾', 'お店 ご存知']
# ['台湾', '掃除 洗剤']
# ['台湾', '場所 お勧め']
# ['台湾', '許可 最低']
# ['台湾', '修繕費 明細']
# ['台湾', '兄弟 里親']
# ['台湾', '日本人 医師']
# ['台湾', '以内 デポジット']
# ['台湾', '直し お店']
# ['台湾', 'クリンスイ 異常']
# ['台湾', '修繕費 デポジット']
# ['台湾', '日本 眼科']
# ['台湾', '子ども クッキング']
# ['台湾', 'シンガポール 英語']
# ['台湾', '日本人 小学校']
# ['台湾', 'スカイスパプールイメージドンピシャバンコク 近郊']
# ['台湾', '日本人 スタッフ']
# ['台湾', '日系 スーパー']
# ['台湾', '情報 交換']
# ['台湾', '日系 幼稚園']
# ['台湾', '予定 台北']
# ['台湾', '詳細 パタヤ']
# ['台湾', 'ご存知 台北']
# ['台湾', '唾液 検査']
# ['台湾', '矯正 クリニック']
# ['台湾', '育児 情報']
# ['台湾', '皆 タイ']
# ['台湾', '値段 高く']
# ['台湾', '日本 チャンギ']
# ['台湾', '販売所 ネット']
# ['台湾', '方法 方法']
# ['台湾', '日本 シンガポール']
# ['台湾', '自分 場合']
# ['台湾', '日本 名字']
# ['台湾', '再生 方法']
# ['台湾', '語学 学校']
# ['台湾', '看護師 介護士']
# ['台湾', 'デパート トイレ']
# ['台湾', '韓国語 初心者']
# ['台湾', 'スクンビット 界隈']
# ['台湾', '情報 近い']
# ['台湾', '女性 病気']
# ['台湾', '在住 日本']
# ['台湾', '市 ニューハーフカツラ']
# ['台湾', 'タイトル 疑問']
# ['台湾', 'タイ 病院']
# ['台湾', 'ご存知 台湾']
# ['台湾', 'フロント 係']
# ['台湾', 'タイ 女性']
# ['台湾', 'マンスリー マンション']
# ['台湾', 'アンケート 回答']
# ['台湾', '野菜 料理']
# ['台湾', '友人 女性']
# ['台湾', '送金 操作']
# ['台湾', '通勤 片道']
# ['台湾', '移動 子連れ']
# ['台湾', '工場 詳しい']
# ['台湾', 'ご存知 ご存知']
# ['台湾', '台湾 後半']
# ['台湾', '情報 埼玉県草加市']
# ['台湾', '家族 ビザ']
# ['台湾', 'タイ 現地']
# ['台湾', '日本 着物']
# ['台湾', '際 台湾']
# ['台湾', '病院 病院']
# ['台湾', 'ペット ホテル']
# ['台湾', '販売所 ネット カンボジア']
# ['台湾', 'バンコク 電子']
# ['台湾', '現地 採用']
# ['台湾', '日本食 レストラン']
# ['台湾', 'アソーク 近辺']
# ['台湾', '窓 レバー']
# ['台湾', 'センター タクシー']
# ['台湾', '台北 美味しい']
# ['台湾', '係員 中国人 上司']
# ['台湾', '個人 台湾']
# ['台湾', '日本語 所']
# ['台湾', 'バルセロナ 拠点']
# ['台湾', 'メイド 日系']
# ['台湾', '水 情報']
# ['台湾', 'ドラム 式']
# ['台湾', '連絡 フロント']
# ['台湾', '教材 日本語']
# ['台湾', '学校 診断書']
# ['台湾', '日本人 美容師']
# ['台湾', 'タイ 日本人']
# ['台湾', '日本 韓国']
# ['台湾', '無理 実際']
# ['台湾', '際 バンコク']
# ['台湾', '美味しい 料理']
# ['台湾', '日本人 会']
# ['台湾', '英語 動物']
# ['台湾', '病院 ご存知']
# ['台湾', '仲介料 自分']
# ['台湾', '次 勤務先']
# ['台湾', '眼科 度数 販売所']
# ['台湾', 'ネット カンボジア']
# ['台湾', '中国語 日本語']
# ['台湾', '事情 お金']
# ['台湾', '治療 丁寧']
# ['台湾', '安い ベット']
# ['台湾', 'サーバー 会社']
# ['台湾', 'クリンスイ 浄水器']
# ['台湾', '施設 ご存知']
# ['台湾', '事 子猫']
# ['台湾', '返金 中旬']
# ['台湾', '歯科 治療']
# ['台湾', '日本 運転免許証']
# ['台湾', '婚約指輪 サイズ']
# ['台湾', '所 ご存知']
# ['台湾', '検査 日本']
# ['台湾', '人材紹介 オフィス']
# ['台湾', 'タバコ 方法']
# ['台湾', '送迎 会社']
# ['台湾', '日本人 台湾']
# ['台湾', '日本語 漫画']
# ['台湾', '調味料 ご存知']
# ['台湾', 'タイム ヨーグルト']
# ['台湾', '詳細 高額']
# ['台湾', 'バンコク 銀行']
# ['台湾', 'シンガポール 日本']
# ['台湾', '患者 電話番号']
# ['台湾', '自分 可能']
# ['台湾', 'ご存知 日系']
# ['台湾', 'ベッドルーム メイド']
# ['台湾', '新實 華語']
# ['台湾', 'ご存知 バンコクファイヤスティックファイヤ']
# ['台湾', '返金 契約書']
# ['台湾', 'プノンペン 運転 手車']
# ['台湾', '日本人 女']
# ['台湾', '排水 管']
# ['台湾', '忘れ物 カメラ']
# ['台湾', 'コンドミニアム 担保']
# ['台湾', '皆 会社']
# ['台湾', '英語 学校']
# ['台湾', '度数 販売所']
# ['台湾', '洗濯機 掃除']
# ['台湾', '基本料金 ボッタクリ']
# ['台湾', '幼稚園 入園']
# ['台湾', '通話 アプリ']
# ['台湾', 'ご存知 日本語']
# ['台湾', '皆 バンコク']
# ['台湾', 'コロナ 影響']
# ['台湾', '問題 サーバー']
# ['台湾', 'お気に入り 患者']
# ['台湾', '東京都 係員 中国人']
# ['台湾', 'クリスマス 息子']
# ['台湾', '変圧器 日本']
# ['台湾', '浄水器 予定']
# ['台湾', '銀行 通帳']
# ['台湾', 'トランジット エリア']
# ['台湾', 'お店 タイ']
# ['台湾', 'シンガポール インターンシップ']
# ['台湾', '野菜 野菜']
# ['台湾', '去勢 性格']
# ['台湾', '友達 娘']
# ['台湾', 'バンコク 日系']
# ['台湾', '単車 無理']
# ['台湾', '在住 詳しい']
# ['台湾', '台灣 大学院']
# ['台湾', '日本 生']
# ['台湾', '経験 メイド']
# ['台湾', '住民票 予定']
# ['台湾', '予定 お店']
# ['台湾', 'エリア 両替']
# ['台湾', '中国人 武蔵野市']
# ['台湾', '施設 シンガポール']
# ['台湾', '掲示板 スタッフ']
# ['台湾', 'サーバー 側']
# ['台湾', 'ビザ 更新']
# ['台湾', '高い シンガポール']
# ['台湾', '娘 ピアノ']
# ['台湾', 'マレーシア 旅行']
# ['台湾', '良かっ 情報']
# ['台湾', '日焼け 防止']
# ['台湾', '日系 サロン']
# ['台湾', '事 学生']
# ['台湾', '思い出 佐賀']
# ['台湾', '必要 シンガポール']
# ['台湾', '際 先']
# ['台湾', '赤川 次郎']
# ['台湾', '運転 手車 場合']
# ['台湾', '朝夕 通勤 片道']
# ['台湾', '治療 保険']
# ['台湾', '家族 旅行']
# ['台湾', '居留 台湾']
# ['台湾', '日系 ローカル']
# ['台湾', 'アプリ 韓国人']
# ['台湾', '矯正歯科 日本語']
# ['台湾', 'カッコ 必要']
# ['台湾', '不安 都市間']
# ['台湾', '台北 日本語']
# ['台湾', '矯正歯科 ホワイト']
# ['台湾', '郵便局 郵便局']
# ['台湾', '単車 アブナイ']
# ['台湾', '方々 意見']
# ['台湾', '返金 無し']
# ['台湾', '日本人 学生']
# ['台湾', '台北 日本']
# ['台湾', '歯科 矯正歯科']
# ['台湾', '美味しい 和食']
# ['台湾', '日本 家族']
# ['台湾', '場合 台湾']
# ['台湾', '意見 車']
# ['台湾', '良い 矯正歯科']
# ['台湾', '度数 販売所 ネット']
# ['台湾', '同時 配信']
# ['台湾', 'お店 トンロー']
# ['台湾', '日本人 特別']
# ['台湾', '脱毛 クリニック']
# ['台湾', '音楽 スタジオ']
# ['台湾', '子供 他']
# ['台湾', '学校 学生']
# ['台湾', '下着 日本']
# ['台湾', 'お店 家具']
# ['台湾', '居留 ビザ']
# ['台湾', '良い 方法']
# ['台湾', 'コンド 備え付け']
# ['台湾', 'バンコク お店']
# ['台湾', '新生児 持ち運び']
# ['台湾', 'タイ 海外']
# ['台湾', '英語 教育']
# ['台湾', 'ローカル 予定']
# ['台湾', '会社 ご存知']
# ['台湾', '隔離 期間']
# ['台湾', '予定 台湾']
# ['台湾', 'ネット サーバー']
# ['台湾', '婦人 八王子']
# ['台湾', '手車 場合']
# ['台湾', '交換 サイト']
# ['台湾', 'クレジットカード 会社']
# ['台湾', '喫煙者 タバコ']
# ['台湾', '学生 ビザ']
# yake ['新北 市', '台北 市', '番組 テレビ', '台北 新北', '名前 年齢', '掲示板 スタッフ', '日本語 授業', '台北 掲示板', '気功 整体', 'アルバイト 時給', '整体 治療', '日本人 スタッフ', 'スタッフ 条件', 'お店 台北', '条件 台北', '新實 華語', '台湾 アルバイト', '教材 日本語', '際 先', '情報 李', '台北 現状', 'ヨーロピアン スクール', '日本人 主婦', '台湾 友人', 'デパート トイレ', 'レンジ 白米', '知り合い 台湾', '市 日本人', '婦人 八王子', '市 お店']
# ['中国', '日本語 教師']
# ['中国', '小児科 先生']
# ['中国', '上巻 下巻']
# ['中国', '日本人 コンド']
# ['中国', '日常 会話']
# ['中国', '娘 一緒']
# ['中国', 'バンコク バンコク']
# ['中国', '金 所']
# ['中国', '大きい サイズ']
# ['中国', '名前 年齢']
# ['中国', 'アンケート 調査']
# ['中国', '教室 ご存知']
# ['中国', '場合 用途 朝夕']
# ['中国', 'アルバイト 時給']
# ['中国', '情報 タイ']
# ['中国', 'コスプレ イヤー']
# ['中国', '仕事 都合']
# ['中国', 'バンコク 在住']
# ['中国', 'ホワイト ドリーム 歯科']
# ['中国', '皆 病院']
# ['中国', '日本人 女性']
# ['中国', '主人 シンガポール']
# ['中国', '保健所 窓口']
# ['中国', '所 事情']
# ['中国', '大学 正規']
# ['中国', '動画 通話']
# ['中国', '場所 マドリード']
# ['中国', '会社 スペイン']
# ['中国', '病院 ペット']
# ['中国', '前 人間']
# ['中国', '必要 情報']
# ['中国', '日本 子供']
# ['中国', '市 お店']
# ['中国', '情報 ご存知']
# ['中国', '事 要件']
# ['中国', '埼玉県草加市 八潮市']
# ['中国', '韓国 韓国語']
# ['中国', '前 香港']
# ['中国', 'カード カード']
# ['中国', '台湾 名字']
# ['中国', '場所 ご存知']
# ['中国', '実費 保険']
# ['中国', 'ホンハム 駅']
# ['中国', '子猫 狂犬病']
# ['中国', 'サイト 香港']
# ['中国', '新北 市']
# ['中国', '日本 香港']
# ['中国', '韓国人 女性']
# ['中国', 'ありがたい 学生']
# ['中国', 'ピアノ ピアノ']
# ['中国', '韓国語 オススメ']
# ['中国', 'ホワイト ドリーム']
# ['中国', '場所 台北']
# ['中国', '市 中国語']
# ['中国', '日本 教育']
# ['中国', '情報 李']
# ['中国', '幼稚園 日本人']
# ['中国', '洗濯機 コンド']
# ['中国', '旅行 予定']
# ['中国', '銀行 タイ']
# ['中国', 'サッカー スクール']
# ['中国', '病気 髪の毛']
# ['中国', '事 日本']
# ['中国', 'ペット 一緒']
# ['中国', '日本 住民票']
# ['中国', '香港 空港']
# ['中国', '日本テレビ 番組']
# ['中国', '子供 一緒']
# ['中国', '電話番号 実際']
# ['中国', '手車 場合 用途']
# ['中国', '情報 シンガポール']
# ['中国', '台湾 際']
# ['中国', '時間帯 混雑']
# ['中国', '正 社員']
# ['中国', '学校 学校']
# ['中国', '自分 台湾']
# ['中国', '香港 歯列']
# ['中国', 'タイ 教育']
# ['中国', '日本語 中国語']
# ['中国', '法 規制']
# ['中国', '野菜 不足']
# ['中国', '仲介手数料 家賃']
# ['中国', '予定 コンド']
# ['中国', 'ビザ 就労']
# ['中国', 'ヨーグルト ユニセックス']
# ['中国', 'ご存知 追記']
# ['中国', '屋内 遊び場']
# ['中国', 'インターンシップ 企業']
# ['中国', '生活 プレーヤー']
# ['中国', '日本人 友達']
# ['中国', '場所 香港']
# ['中国', '英語 タイ']
# ['中国', '健康 診断書']
# ['中国', '安定性 サーバー']
# ['中国', '賃料 仲介手数料']
# ['中国', '里親 コンドミニアム']
# ['中国', '窓口 中国人']
# ['中国', '台湾 アルバイト']
# ['中国', '上海 赴任']
# ['中国', '母 家族']
# ['中国', 'コンド コンド']
# ['中国', '香港 仕事']
# ['中国', '知り合い 台湾']
# ['中国', '下巻 シドニー']
# ['中国', '都市 都市']
# ['中国', 'コロナ 禍']
# ['中国', 'タイシルクシンプルシルク 下着']
# ['中国', '記事 記事']
# ['中国', 'エリア 場所']
# ['中国', '病院 ラッフルズ']
# ['中国', 'バンコク 市']
# ['中国', '狂犬病 期間']
# ['中国', '勧め 歯医者']
# ['中国', '歯科 サムスン']
# ['中国', '成田 係員']
# ['中国', 'お店 バンコク']
# ['中国', 'ワクチン 必要']
# ['中国', 'シドニー シェルダン']
# ['中国', '場所 中国語']
# ['中国', '高額 修繕費']
# ['中国', '家具 家電']
# ['中国', '生 クリーム']
# ['中国', '日本人 主婦']
# ['中国', '台北 新北']
# ['中国', '条件 台北']
# ['中国', '学校教育 企業']
# ['中国', '通勤 片道 カンボジアコンタクトレンズ']
# ['中国', '日本 幼稚園']
# ['中国', '日本 事']
# ['中国', 'エレクトロニクス 関係']
# ['中国', '日本人 多い']
# ['中国', 'ウェイパー 調味料']
# ['中国', '外来 日本語']
# ['中国', '以下 除湿器']
# ['中国', '台湾 就労ビザ']
# ['中国', '都市 学生']
# ['中国', 'お店 ネット']
# ['中国', '中国人 上司']
# ['中国', '方法 宿']
# ['中国', 'ニューハーフカツラ 問屋街']
# ['中国', 'ヘアカット 専門店']
# ['中国', 'サイト 近所']
# ['中国', 'ビザタイ 人材紹介']
# ['中国', '木下 グループ']
# ['中国', '料理 タイ']
# ['中国', '会社 日本人']
# ['中国', 'バンコク 病院']
# ['中国', '歯科 医院']
# ['中国', '八潮市 カット']
# ['中国', '教育 親']
# ['中国', '画面 方法']
# ['中国', '予定 バルセロナ']
# ['中国', '台湾 日本']
# ['中国', 'タイ 物']
# ['中国', '作り方 分量']
# ['中国', '台灣 ビザ']
# ['中国', '日本 眼科 度数']
# ['中国', '日本人 少ない']
# ['中国', '就労 質問']
# ['中国', 'センター カウンター']
# ['中国', '語 お仕事']
# ['中国', 'おすすめ 香港']
# ['中国', '大学 在学']
# ['中国', '他 先生']
# ['中国', '髪の毛 友達']
# ['中国', '台北 子供']
# ['中国', '問題 台北']
# ['中国', '丁寧 先生']
# ['中国', 'お店 お店']
# ['中国', 'ためよう 情報']
# ['中国', 'セグメント ネット']
# ['中国', '中原 大学']
# ['中国', '主人 バンコク']
# ['中国', '空港 ホンハム']
# ['中国', '家賃 半額']
# ['中国', 'サロン 自然']
# ['中国', '語学 研修']
# ['中国', '学校 現金']
# ['中国', '言いがかり デポジット']
# ['中国', '可能 台湾']
# ['中国', '係員 中国人']
# ['中国', '企業 メンバー']
# ['中国', '場所 現地']
# ['中国', '案内 中国人']
# ['中国', '国産 ワクチン']
# ['中国', '病院 日本語']
# ['中国', '語 英語']
# ['中国', '要件 許可']
# ['中国', 'バルセロナ 旅行']
# ['中国', '大学 外国人']
# ['中国', '幼稚園 台北']
# ['中国', 'カンボジア 法']
# ['中国', '先生 お気に入り']
# ['中国', '不動産 契約']
# ['中国', '家族 日本人']
# ['中国', '動物 病院']
# ['中国', '入金 可能']
# ['中国', '日本 企業']
# ['中国', '予定 中国語']
# ['中国', '楽しく バンコク']
# ['中国', '宿 バルセロナ']
# ['中国', '観光 ビザ']
# ['中国', '日本人 場所']
# ['中国', '航空会社 コールセンター']
# ['中国', '先生 病院']
# ['中国', '学費 補助']
# ['中国', 'おすすめ ホテル']
# ['中国', '嬉しい シンガポール']
# ['中国', '実際 小児科']
# ['中国', '中国語 子供']
# ['中国', 'バンコク ペット']
# ['中国', '台北 掲示板']
# ['中国', '幼稚園 送迎']
# ['中国', '詳しく 香港']
# ['中国', 'ユニセックス ヘアカット']
# ['中国', 'アドバイス 幼稚園']
# ['中国', '混雑 状況']
# ['中国', '質問 バンコク']
# ['中国', '無い 場合']
# ['中国', 'バンコク 日本人']
# ['中国', '用途 朝夕 通勤']
# ['中国', '学校 ご存知']
# ['中国', '先生 ご存知']
# ['中国', '医療 場合']
# ['中国', '日本 日本']
# ['中国', 'レンジ 白米']
# ['中国', 'ビザ 取得']
# ['中国', '広州 予定']
# ['中国', '友達 場所']
# ['中国', '物件 自分']
# ['中国', '情報 嬉しい']
# ['中国', '手探り 状態']
# ['中国', '者 ご存知']
# ['中国', '拠点 グラナダ']
# ['中国', 'アクセス よい']
# ['中国', '整体 治療']
# ['中国', 'タイ 語']
# ['中国', 'タイ 日本']
# ['中国', '自分 現地']
# ['中国', 'シンガポール マレーシア']
# ['中国', '日本語 英語']
# ['中国', '丁寧 いつも']
# ['中国', 'カンボジアコンタクトレンズ 日本']
# ['中国', '妻 生活']
# ['中国', '東京都 係員']
# ['中国', '眼科 度数']
# ['中国', '台湾 友人']
# ['中国', '特別 観光']
# ['中国', '番組 テレビ']
# ['中国', '外出 禁止']
# ['中国', 'バンコク 良い']
# ['中国', 'オンライン ショップ']
# ['中国', '日本語 授業']
# ['中国', '可能 銀行']
# ['中国', '場合 風呂']
# ['中国', 'スペイン語 日常']
# ['中国', '家族 友人']
# ['中国', '際 手続き']
# ['中国', '分量 製品']
# ['中国', '外国人 不法']
# ['中国', '日本 プライム']
# ['中国', '場所 子連れ']
# ['中国', 'インター 幼稚園']
# ['中国', 'コロナ ワクチン']
# ['中国', '企業 サービス']
# ['中国', '契約 押金']
# ['中国', '日本人 日本語']
# ['中国', '頭 古い']
# ['中国', 'チーム 深セン']
# ['中国', '小学校 学費']
# ['中国', '治療 病院']
# ['中国', '香港ドル 日本円']
# ['中国', '実際 ビザ']
# ['中国', '日本人 学校']
# ['中国', '英語 オンライン']
# ['中国', '中国語 幼稚園']
# ['中国', '中国語 学校']
# ['中国', '半年 契約社員']
# ['中国', '他 会場']
# ['中国', '台北 市']
# ['中国', 'お店 情報']
# ['中国', '日本 スペイン']
# ['中国', '韓国 在住']
# ['中国', '既婚 友達']
# ['中国', '英語 中国語']
# ['中国', 'スタッフ 条件']
# ['中国', '幼稚園 対策']
# ['中国', 'お店 台湾']
# ['中国', '幼稚園 日本語']
# ['中国', '店舗 店舗']
# ['中国', '一緒 里親']
# ['中国', 'クリンスイ 普通']
# ['中国', '予定 育児']
# ['中国', '日本 タイ']
# ['中国', 'タイ 皆']
# ['中国', 'スクンビット 近辺']
# ['中国', 'みな 対策']
# ['中国', '一般的 次']
# ['中国', '幼稚園 英語']
# ['中国', 'ローカル 日系']
# ['中国', '江南駅 近く']
# ['中国', 'アヤ 退職金']
# ['中国', 'ご存知 嬉しい']
# ['中国', '海外 美容師']
# ['中国', 'バンコクファイヤスティックファイヤ 日本']
# ['中国', '香港 者']
# ['中国', 'ヨーロピアン スクール']
# ['中国', '実 友人']
# ['中国', '分 サービス料']
# ['中国', '狂犬病 注射']
# ['中国', '日本人 インド人']
# ['中国', '最低 事']
# ['中国', '日本人 ワークパーミッド']
# ['中国', '中国人 日本人']
# ['中国', '市 日本']
# ['中国', '朝夕 通勤']
# ['中国', 'アメリカ人 ためよう']
# ['中国', 'お金 必要']
# ['中国', '係員 ワクチン']
# ['中国', '指導 中学生']
# ['中国', '記事 お店']
# ['中国', '台北 在住']
# ['中国', 'お店 台北']
# ['中国', '都市間 移動']
# ['中国', '医院 個人']
# ['中国', '朝 夕方']
# ['中国', '調査 チーム']
# ['中国', '情報 上海']
# ['中国', '子供 用品']
# ['中国', 'グラナダ 子ども']
# ['中国', '日本 荷物']
# ['中国', '近く ホワイト']
# ['中国', '子供 場所']
# ['中国', 'ドリーム 歯科']
# ['中国', 'バンコク 生活']
# ['中国', '前髪 前髪']
# ['中国', 'オンライン 送金']
# ['中国', '水野 敬也']
# ['中国', 'プレーヤー 欲しい']
# ['中国', '名前 お店']
# ['中国', 'クッキング 教室']
# ['中国', '歯ブラシ セット']
# ['中国', '着物 着物']
# ['中国', 'バレンシア 大学']
# ['中国', '予定 コロナ']
# ['中国', '男性 次']
# ['中国', '市 新米']
# ['中国', '多い 日本']
# ['中国', 'スペイン 旅行']
# ['中国', '際 関税']
# ['中国', '台北 現状']
# ['中国', 'ご存知 詳細']
# ['中国', '病院 日本人']
# ['中国', '半袖 ジャケット']
# ['中国', 'アニメ 英語']
# ['中国', '医院 今ひとつ']
# ['中国', '方法 ご存知']
# ['中国', '市 幼稚園']
# ['中国', '日本 際']
# ['中国', 'カンボジア 法 規制']
# ['中国', '市 日本人']
# ['中国', 'ドイツ人 学校']
# ['中国', '近郊 施設']
# ['中国', '感染 状況']
# ['中国', 'ローカル 日本語']
# ['中国', '病院 ご存じ']
# ['中国', '新生児 ミルク']
# ['中国', 'シンガポール 在住']
# ['中国', '携帯 会社']
# ['中国', '小児科 他']
# ['中国', 'タバコ 部屋']
# ['中国', '場所 情報']
# ['中国', '都市 更新']
# ['中国', 'サイド スポイラー']
# ['中国', '英語 対応']
# ['中国', 'バンコク 旅行']
# ['中国', '日本人 自分']
# ['中国', 'カード 特典']
# ['中国', 'オーナー 高額']
# ['中国', 'ラビット カード']
# ['中国', 'キッチン スペース']
# ['中国', '必要 日本']
# ['中国', '台北 観光']
# ['中国', '保育園 幼稚園']
# ['中国', '着物 帯']
# ['中国', '中学生 教育費']
# ['中国', 'カット タイム']
# ['中国', '子ども 小さい']
# ['中国', '警察 レポート']
# ['中国', '気功 整体']
# ['中国', 'ローカル 病院']
# ['中国', '日本人 対象']
# ['中国', 'ご存知 バンコク']
# ['中国', '中国人 上司 中国人']
# ['中国', 'シンガポール 日本人']
# ['中国', '在学 証明']
# ['中国', '日本 予定']
# ['中国', 'ご存知 日本']
# ['中国', '係留 施設']
# ['中国', '歯科 通訳']
# ['中国', 'タイ 料理']
# ['中国', '友達 友達']
# ['中国', 'カメラ セビリア']
# ['中国', '電子 ピアノ']
# ['中国', 'デポジット 返金']
# ['中国', '他 友達']
# ['中国', 'おすすめ サロン']
# ['中国', '用途 朝夕']
# ['中国', '味覇 ウェイパー']
# ['中国', 'ミルク 作り方']
# ['中国', '江東区 保健所']
# ['中国', '多い 気']
# ['中国', '返答 修繕費']
# ['中国', 'ご存知 日本人']
# ['中国', '台湾 予定']
# ['中国', '活動 深セン']
# ['中国', '学校 中国語']
# ['中国', 'シンガポール 美容室']
# ['中国', '運転 手車']
# ['中国', '仕方 ビザタイ']
# ['中国', '在住 日本人']
# ['中国', '式 洗濯機']
# ['中国', 'すすめ 情報']
# ['中国', '本 際']
# ['中国', 'ローカル 美容院']
# ['中国', '者 クリンスイ']
# ['中国', '語 検定']
# ['中国', '業 者']
# ['中国', '矯正 丁寧']
# ['中国', 'プライム ビデオ']
# ['中国', 'お店 ご存知']
# ['中国', '掃除 洗剤']
# ['中国', '場所 お勧め']
# ['中国', '許可 最低']
# ['中国', '修繕費 明細']
# ['中国', '兄弟 里親']
# ['中国', '日本人 医師']
# ['中国', '以内 デポジット']
# ['中国', '直し お店']
# ['中国', 'クリンスイ 異常']
# ['中国', '修繕費 デポジット']
# ['中国', '日本 眼科']
# ['中国', '子ども クッキング']
# ['中国', 'シンガポール 英語']
# ['中国', '日本人 小学校']
# ['中国', 'スカイスパプールイメージドンピシャバンコク 近郊']
# ['中国', '日本人 スタッフ']
# ['中国', 'ご存知 上海']
# ['中国', '日系 スーパー']
# ['中国', '情報 交換']
# ['中国', '日系 幼稚園']
# ['中国', '予定 台北']
# ['中国', '詳細 パタヤ']
# ['中国', 'ご存知 台北']
# ['中国', '唾液 検査']
# ['中国', '矯正 クリニック']
# ['中国', '育児 情報']
# ['中国', '皆 タイ']
# ['中国', '値段 高く']
# ['中国', '日本 チャンギ']
# ['中国', '販売所 ネット']
# ['中国', '方法 方法']
# ['中国', '日本 シンガポール']
# ['中国', '自分 場合']
# ['中国', '証明 証明']
# ['中国', '日本 名字']
# ['中国', '再生 方法']
# ['中国', '語学 学校']
# ['中国', '看護師 介護士']
# ['中国', 'デパート トイレ']
# ['中国', '韓国語 初心者']
# ['中国', 'スクンビット 界隈']
# ['中国', '情報 近い']
# ['中国', '女性 病気']
# ['中国', '在住 日本']
# ['中国', '市 ニューハーフカツラ']
# ['中国', 'タイトル 疑問']
# ['中国', 'タイ 病院']
# ['中国', 'ご存知 台湾']
# ['中国', 'フロント 係']
# ['中国', 'タイ 女性']
# ['中国', 'マンスリー マンション']
# ['中国', 'アンケート 回答']
# ['中国', '野菜 料理']
# ['中国', '友人 女性']
# ['中国', '送金 操作']
# ['中国', '通勤 片道']
# ['中国', '移動 子連れ']
# ['中国', '工場 詳しい']
# ['中国', 'ご存知 ご存知']
# ['中国', '台湾 後半']
# ['中国', '情報 埼玉県草加市']
# ['中国', '家族 ビザ']
# ['中国', 'タイ 現地']
# ['中国', '日本 着物']
# ['中国', '際 台湾']
# ['中国', '教育 テーマ']
# ['中国', '病院 病院']
# ['中国', '企業 水谷']
# ['中国', 'ペット ホテル']
# ['中国', '販売所 ネット カンボジア']
# ['中国', '深圳 深圳']
# ['中国', 'バンコク 電子']
# ['中国', '現地 採用']
# ['中国', '日本食 レストラン']
# ['中国', 'アソーク 近辺']
# ['中国', '窓 レバー']
# ['中国', 'センター タクシー']
# ['中国', '台北 美味しい']
# ['中国', '係員 中国人 上司']
# ['中国', '個人 台湾']
# ['中国', '日本語 所']
# ['中国', 'バルセロナ 拠点']
# ['中国', 'メイド 日系']
# ['中国', '水 情報']
# ['中国', 'ドラム 式']
# ['中国', '連絡 フロント']
# ['中国', '教材 日本語']
# ['中国', '学校 診断書']
# ['中国', '日本人 美容師']
# ['中国', 'タイ 日本人']
# ['中国', '日本 韓国']
# ['中国', '無理 実際']
# ['中国', '際 バンコク']
# ['中国', '美味しい 料理']
# ['中国', '日本人 会']
# ['中国', '英語 動物']
# ['中国', '病院 ご存知']
# ['中国', '仲介料 自分']
# ['中国', '次 勤務先']
# ['中国', '眼科 度数 販売所']
# ['中国', 'ネット カンボジア']
# ['中国', '中国語 日本語']
# ['中国', '事情 お金']
# ['中国', 'お店 上海']
# ['中国', '治療 丁寧']
# ['中国', '安い ベット']
# ['中国', 'サーバー 会社']
# ['中国', 'クリンスイ 浄水器']
# ['中国', '施設 ご存知']
# ['中国', '事 子猫']
# ['中国', '返金 中旬']
# ['中国', '歯科 治療']
# ['中国', '深セン 教育']
# ['中国', '日本 運転免許証']
# ['中国', '婚約指輪 サイズ']
# ['中国', '所 ご存知']
# ['中国', '検査 日本']
# ['中国', '人材紹介 オフィス']
# ['中国', 'タバコ 方法']
# ['中国', '送迎 会社']
# ['中国', '企業 スタートアップ']
# ['中国', '日本人 台湾']
# ['中国', '押金 賃料']
# ['中国', '日本語 漫画']
# ['中国', '調味料 ご存知']
# ['中国', 'タイム ヨーグルト']
# ['中国', '詳細 高額']
# ['中国', 'バンコク 銀行']
# ['中国', '台北 中国人']
# ['中国', 'シンガポール 日本']
# ['中国', '患者 電話番号']
# ['中国', '自分 可能']
# ['中国', 'ご存知 日系']
# ['中国', 'ベッドルーム メイド']
# ['中国', '新實 華語']
# ['中国', 'ご存知 バンコクファイヤスティックファイヤ']
# ['中国', '返金 契約書']
# ['中国', 'プノンペン 運転 手車']
# ['中国', '日本人 女']
# ['中国', '排水 管']
# ['中国', '忘れ物 カメラ']
# ['中国', 'コンドミニアム 担保']
# ['中国', '皆 会社']
# ['中国', '英語 学校']
# ['中国', '度数 販売所']
# ['中国', '洗濯機 掃除']
# ['中国', '基本料金 ボッタクリ']
# ['中国', '幼稚園 入園']
# ['中国', '通話 アプリ']
# ['中国', 'ご存知 日本語']
# ['中国', '皆 バンコク']
# ['中国', '企業 調査']
# ['中国', 'コロナ 影響']
# ['中国', '虹橋 空港']
# ['中国', '問題 サーバー']
# ['中国', 'お気に入り 患者']
# ['中国', '東京都 係員 中国人']
# ['中国', 'クリスマス 息子']
# ['中国', '変圧器 日本']
# ['中国', '浄水器 予定']
# ['中国', '銀行 通帳']
# ['中国', 'トランジット エリア']
# ['中国', 'お店 タイ']
# ['中国', 'シンガポール インターンシップ']
# ['中国', '野菜 野菜']
# ['中国', '去勢 性格']
# ['中国', '友達 娘']
# ['中国', 'バンコク 日系']
# ['中国', '単車 無理']
# ['中国', '在住 詳しい']
# ['中国', '台灣 大学院']
# ['中国', '日本 生']
# ['中国', '経験 メイド']
# ['中国', '住民票 予定']
# ['中国', 'メンバー 調査']
# ['中国', '予定 お店']
# ['中国', 'エリア 両替']
# ['中国', '中国人 武蔵野市']
# ['中国', '施設 シンガポール']
# ['中国', '掲示板 スタッフ']
# ['中国', 'サーバー 側']
# ['中国', 'ビザ 更新']
# ['中国', '高い シンガポール']
# ['中国', '娘 ピアノ']
# ['中国', 'マレーシア 旅行']
# ['中国', '良かっ 情報']
# ['中国', '日焼け 防止']
# ['中国', '日系 サロン']
# ['中国', '事 学生']
# ['中国', '思い出 佐賀']
# ['中国', '必要 シンガポール']
# ['中国', '際 先']
# ['中国', '赤川 次郎']
# ['中国', '運転 手車 場合']
# ['中国', '朝夕 通勤 片道']
# ['中国', '治療 保険']
# ['中国', '家族 旅行']
# ['中国', '居留 台湾']
# ['中国', '日系 ローカル']
# ['中国', 'アプリ 韓国人']
# ['中国', '矯正歯科 日本語']
# ['中国', 'カッコ 必要']
# ['中国', '不安 都市間']
# ['中国', '台北 日本語']
# ['中国', '矯正歯科 ホワイト']
# ['中国', '郵便局 郵便局']
# ['中国', '単車 アブナイ']
# ['中国', '方々 意見']
# ['中国', '返金 無し']
# ['中国', '日本人 学生']
# ['中国', '台北 日本']
# ['中国', '歯科 矯正歯科']
# ['中国', '市 教育']
# ['中国', '美味しい 和食']
# ['中国', '日本 家族']
# ['中国', '場合 台湾']
# ['中国', '意見 車']
# ['中国', '良い 矯正歯科']
# ['中国', '度数 販売所 ネット']
# ['中国', '同時 配信']
# ['中国', 'お店 トンロー']
# ['中国', '日本人 特別']
# ['中国', '脱毛 クリニック']
# ['中国', '音楽 スタジオ']
# ['中国', '子供 他']
# ['中国', '学校 学生']
# ['中国', '下着 日本']
# ['中国', 'お店 家具']
# ['中国', '居留 ビザ']
# ['中国', '良い 方法']
# ['中国', 'コンド 備え付け']
# ['中国', 'バンコク お店']
# ['中国', '新生児 持ち運び']
# ['中国', '浦東 空港']
# ['中国', 'タイ 海外']
# ['中国', '英語 教育']
# ['中国', 'ローカル 予定']
# ['中国', '会社 ご存知']
# ['中国', '隔離 期間']
# ['中国', '予定 台湾']
# ['中国', 'ネット サーバー']
# ['中国', '婦人 八王子']
# ['中国', '手車 場合']
# ['中国', '交換 サイト']
# ['中国', 'クレジットカード 会社']
# ['中国', '喫煙者 タバコ']
# ['中国', '学生 ビザ']
# yake ['日本 企業', '押金 賃料', '証明 証明', '企業 調査', '賃料 仲介手数料', '在学 証明', 'コスプレ イヤー', '仲介手数料 家賃', '企業 水谷', '企業 スタートアップ', '企業 メンバー', '契約 押金', '深セン 教育', '広州 予定', '調査 チーム', '香港ドル 日本円', '日本人 場所', '日本人 多い', '中国語 学校', '学校教育 企業', '市 教育', 'メンバー 調査', 'チーム 深セン', '教育 テーマ', '不動産 契約', '家賃 半額', '活動 深セン', '日本 教育', '大学 在学', '教育 親']

# %%
#spacy
op_csv='/content/drive/MyDrive/out/'
countStr="オーストラリア"
def run(line):
  with open(op_csv+countStr+(".csv"), newline='') as f:
    lines = f.readlines()
  chunks = [' '.join(line[i:i+100]) for i in range(0, len(line), 100)]
  taken=[]
  sl=stopwords_text()
  for tok in chunks:
    # rmPOS=preprocessPOS(tok)
    # text = preprocess(rmPOS)
    # doc = create_doc(text)

    rmPOS="".join(tok)
    # text = preprocess(rmPOS)
    doc = create_doc(rmPOS)

    for tok in doc.ents:
      if tok.text:
        print(tok.text,"   ",tok.label_)
        taken.append(tok.text)

  print(set(taken))

  # sl=stopwords_text()
  # result=[]

  # for token in x.split( ):
  #   # print(token)
  #   if not token in sl:
  #     result.append(token)
  # w=set(result)
  # strResult=  " ".join(w)# list -> str 
  # # print(strResult)

# %%
run(lines)
